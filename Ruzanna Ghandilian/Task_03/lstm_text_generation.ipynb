# %% [markdown]
# # Text Generation with LSTM
# **Dataset:** Frankenstein (Project Gutenberg)
# **Framework:** PyTorch
# **Architecture:** Embedding → LSTM → Fully-Connected
#
# This notebook solves the same text-generation problem as the RNN version,
# but replaces the Elman RNN cell with an **LSTM** (Long Short-Term Memory) cell.
#
# ### Key differences vs. the RNN version
# | Aspect | Elman RNN | LSTM |
# |--------|-----------|------|
# | Hidden state | single vector `h` | cell state `c` + hidden state `h` |
# | Gates | none | input, forget, output |
# | Vanishing gradient | severe | mitigated by cell highway |
# | Module | `nn.RNN` | `nn.LSTM` |
# | Forward return | `(out, h_new)` | `(out, (h_new, c_new))` |

# %% [markdown]
# ## 1. Imports

# %%
import re
import random
import math
import urllib.request
from collections import Counter

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

print("PyTorch version:", torch.__version__)
print("Device:", "cuda" if torch.cuda.is_available() else "cpu")
# Out:
# PyTorch version: 2.7.0+cu118
# Device: cuda

# %% [markdown]
# ## 2. Dataset Preparation
#
# Identical to the RNN notebook — same corpus, same vocabulary, same sliding-window sequences.
#
# | Variable | Value |
# |----------|-------|
# | `WINDOW_SIZE` | 100 |
# | Input length | 99 tokens |
# | Target | 1 token (next word) |

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────────
WINDOW_SIZE = 100        # input seq_len = 99, target = 1
VOCAB_CAP   = 5_000      # keep top-N words
URL = "https://www.gutenberg.org/cache/epub/84/pg84-images.html"

# ── 2.1  Fetch & clean text ───────────────────────────────────────────────────
print("Fetching Frankenstein …")
try:
    with urllib.request.urlopen(URL, timeout=30) as r:
        html = r.read().decode("utf-8", errors="ignore")
    text = re.sub(r"<[^>]+>", " ", html)
    text = re.sub(r"\s+", " ", text).strip()
    print(f"  Downloaded {len(text):,} characters")
except Exception as e:
    print(f"  Network error ({e}) – using fallback text")
    text = (
        "It was on a dreary night of November that I beheld the accomplishment "
        "of my toils. With an anxiety that almost amounted to agony, I collected "
        "the instruments of life around me that I might infuse a spark of being "
        "into the lifeless thing that lay at my feet. It was already one in the "
        "morning the rain pattered dismally against the panes and my candle was "
        "nearly burnt out when by the glimmer of the half-extinguished light I "
        "saw the dull yellow eye of the creature open it breathed hard and a "
        "convulsive motion agitated its limbs. How can I describe my emotions at "
        "this catastrophe or how delineate the wretch whom with such infinite "
        "pains and care I had endeavoured to form. His limbs were in proportion "
        "and I had selected his features as beautiful. Beautiful Great God His "
        "yellow skin scarcely covered the work of muscles and arteries beneath "
        "his hair was of a lustrous black and flowing his teeth of a pearly "
        "whiteness but these luxuriances only formed a more horrid contrast. "
    ) * 80

# ── 2.2  Tokenise ─────────────────────────────────────────────────────────────
all_tokens = re.findall(r"[a-z']+", text.lower())
print(f"  Total tokens : {len(all_tokens):,}")
# Out:
# Fetching Frankenstein …
#   Downloaded 439,999 characters
#   Total tokens : 78,771

# %%
# ── 2.3  Vocabulary ───────────────────────────────────────────────────────────
freq      = Counter(all_tokens)
top_words = [w for w, _ in freq.most_common(VOCAB_CAP - 1)]
word2idx  = {"<UNK>": 0}
word2idx.update({w: i + 1 for i, w in enumerate(top_words)})
idx2word  = {i: w for w, i in word2idx.items()}
VOCAB_SIZE = len(word2idx)
print(f"  Vocabulary size : {VOCAB_SIZE}")
# Out:
#   Vocabulary size : 5000

# %%
# ── 2.4  Encode & build sliding-window sequences ──────────────────────────────
SEQ_LEN = WINDOW_SIZE - 1   # 99

encoded = [word2idx.get(t, 0) for t in all_tokens]

data    = [encoded[i : i + SEQ_LEN]  for i in range(len(encoded) - WINDOW_SIZE + 1)]
targets = [encoded[i + SEQ_LEN]      for i in range(len(encoded) - WINDOW_SIZE + 1)]

print(f"  Number of sequences : {len(data):,}")
print(f"  Input length        : {SEQ_LEN}")
print(f"  First input sample  : {data[0][:10]} …")
print(f"  First target        : {targets[0]}  ('{idx2word[targets[0]]}')")
# Out:
#   Number of sequences : 78,672
#   Input length        : 99
#   First input sample  : [490, 991, 1415, 490, 1242, 1415, 37, 2370, 1636, 2371] …
#   First target        : 173  ('margin')

# %% [markdown]
# ## 3. PyTorch Dataset & DataLoader

# %%
class TextDataset(Dataset):
    def __init__(self, seqs, tgts):
        self.X = torch.tensor(seqs, dtype=torch.long)
        self.y = torch.tensor(tgts, dtype=torch.long)
    def __len__(self):
        return len(self.y)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

BATCH = 128
random.seed(42)
indices = list(range(len(data))); random.shuffle(indices)
split   = int(0.9 * len(indices))

train_ds = TextDataset([data[i] for i in indices[:split]],
                       [targets[i] for i in indices[:split]])
val_ds   = TextDataset([data[i] for i in indices[split:]],
                       [targets[i] for i in indices[split:]])

train_loader = DataLoader(train_ds, batch_size=BATCH, shuffle=True,  drop_last=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH, shuffle=False, drop_last=False)

print(f"Train batches : {len(train_loader):,}")
print(f"Val   batches : {len(val_loader):,}")
# Out:
# Train batches : 553
# Val   batches : 62

# %% [markdown]
# ## 4. LSTM Model

# %%
class TextLSTM(nn.Module):
    def __init__(self, vocab_size, embed_dim=64, hidden_dim=256, num_layers=1):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        # ← Only change: nn.RNN → nn.LSTM  (same signature, different cell)
        self.lstm  = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers,
                             batch_first=True)
        self.fc    = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden=None):
        emb           = self.embed(x)              # (B, T, E)
        out, hidden_new = self.lstm(emb, hidden)   # hidden_new = (h, c)  ← tuple!
        logits        = self.fc(out[:, -1, :])     # last timestep → (B, V)
        return logits, hidden_new

device = "cuda" if torch.cuda.is_available() else "cpu"

EMBED_DIM  = 64
HIDDEN_DIM = 256

model = TextLSTM(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM).to(device)
total_params = sum(p.numel() for p in model.parameters())
print(model)
print(f"\nTotal parameters: {total_params:,}")
print()
print("Parameter count comparison:")
print(f"  RNN  (same dims): ~1,687,432")
print(f"  LSTM (this model): {total_params:,}  (~4× more — 4 gates vs 1)")
# Out:
# TextLSTM(
#   (embed): Embedding(5000, 64, padding_idx=0)
#   (lstm): LSTM(64, 256, batch_first=True)
#   (fc): Linear(in_features=256, out_features=5000, bias=True)
# )
#
# Total parameters: 1,934,728
#
# Parameter count comparison:
#   RNN  (same dims): ~1,687,432
#   LSTM (this model): 1,934,728  (~4× more — 4 gates vs 1)

# %% [markdown]
# ## 5. Training

# %%
LR     = 1e-3
EPOCHS = 30
CLIP   = 5.0

criterion = nn.CrossEntropyLoss()
optimiser = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.StepLR(optimiser, step_size=2, gamma=0.5)

train_losses, val_perplexities = [], []

for epoch in range(1, EPOCHS + 1):
    # ── Train ─────────────────────────────────────────────────
    model.train()
    running = 0.0
    for step, (xb, yb) in enumerate(train_loader):
        xb, yb = xb.to(device), yb.to(device)
        optimiser.zero_grad()
        logits, _ = model(xb)          # hidden state discarded between batches
        loss = criterion(logits, yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), CLIP)
        optimiser.step()
        running += loss.item()
        if (step + 1) % 300 == 0:
            print(f"  Epoch {epoch} | step {step+1:>5}/{len(train_loader)}"
                  f" | loss {running/(step+1):.4f}")

    avg_train = running / len(train_loader)
    train_losses.append(avg_train)

    # ── Validate ──────────────────────────────────────────────
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            logits, _ = model(xb)
            val_loss += criterion(logits, yb).item()
    ppl = math.exp(val_loss / len(val_loader))
    val_perplexities.append(ppl)

    print(f"\n{'─'*60}")
    print(f"Epoch {epoch}  |  train_loss {avg_train:.4f}  |  val_perplexity {ppl:.2f}")
    print(f"{'─'*60}\n")
    scheduler.step()
# Out:
#   Epoch 1 | step   300/553 | loss 6.4337
#
# ────────────────────────────────────────────────────────────
# Epoch 1  |  train_loss 6.2524  |  val_perplexity 380.67
# ────────────────────────────────────────────────────────────
#
#   Epoch 2 | step   300/553 | loss 5.6556
#
# ────────────────────────────────────────────────────────────
# Epoch 2  |  train_loss 5.5953  |  val_perplexity 284.75
# ────────────────────────────────────────────────────────────
#
#   Epoch 3 | step   300/553 | loss 5.1758
#
# ────────────────────────────────────────────────────────────
# Epoch 3  |  train_loss 5.1599  |  val_perplexity 257.60
# ────────────────────────────────────────────────────────────
#
#   Epoch 4 | step   300/553 | loss 4.9028
#
# ────────────────────────────────────────────────────────────
# Epoch 4  |  train_loss 4.9218  |  val_perplexity 246.41
# ────────────────────────────────────────────────────────────
#
#   Epoch 5 | step   300/553 | loss 4.6658
#
# ────────────────────────────────────────────────────────────
# Epoch 5  |  train_loss 4.6742  |  val_perplexity 244.53
# ────────────────────────────────────────────────────────────
#
#   Epoch 6 | step   300/553 | loss 4.5549
#
# ────────────────────────────────────────────────────────────
# Epoch 6  |  train_loss 4.5563  |  val_perplexity 244.33
# ────────────────────────────────────────────────────────────
#
#   Epoch 7 | step   300/553 | loss 4.4214
#
# ────────────────────────────────────────────────────────────
# Epoch 7  |  train_loss 4.4264  |  val_perplexity 243.99
# ────────────────────────────────────────────────────────────
#
#   Epoch 8 | step   300/553 | loss 4.3660
#
# ────────────────────────────────────────────────────────────
# Epoch 8  |  train_loss 4.3686  |  val_perplexity 246.90
# ────────────────────────────────────────────────────────────
#
#   Epoch 9 | step   300/553 | loss 4.2967
#
# ────────────────────────────────────────────────────────────
# Epoch 9  |  train_loss 4.3028  |  val_perplexity 245.96
# ────────────────────────────────────────────────────────────
#
#   Epoch 10 | step   300/553 | loss 4.2676
#
# ────────────────────────────────────────────────────────────
# Epoch 10  |  train_loss 4.2745  |  val_perplexity 247.55
# ────────────────────────────────────────────────────────────
#
#   Epoch 11 | step   300/553 | loss 4.2480
#
# ────────────────────────────────────────────────────────────
# Epoch 11  |  train_loss 4.2414  |  val_perplexity 248.14
# ────────────────────────────────────────────────────────────
#
#   Epoch 12 | step   300/553 | loss 4.2191
#
# ────────────────────────────────────────────────────────────
# Epoch 12  |  train_loss 4.2277  |  val_perplexity 248.25
# ────────────────────────────────────────────────────────────
#
#   Epoch 13 | step   300/553 | loss 4.2018
#
# ────────────────────────────────────────────────────────────
# Epoch 13  |  train_loss 4.2112  |  val_perplexity 248.19
# ────────────────────────────────────────────────────────────
#
#   Epoch 14 | step   300/553 | loss 4.2071
#
# ────────────────────────────────────────────────────────────
# Epoch 14  |  train_loss 4.2046  |  val_perplexity 248.73
# ────────────────────────────────────────────────────────────
#
#   Epoch 15 | step   300/553 | loss 4.2111
#
# ────────────────────────────────────────────────────────────
# Epoch 15  |  train_loss 4.1964  |  val_perplexity 249.10
# ────────────────────────────────────────────────────────────
#
#   Epoch 16 | step   300/553 | loss 4.1931
#
# ────────────────────────────────────────────────────────────
# Epoch 16  |  train_loss 4.1930  |  val_perplexity 249.40
# ────────────────────────────────────────────────────────────
#
#   Epoch 17 | step   300/553 | loss 4.1779
#
# ────────────────────────────────────────────────────────────
# Epoch 17  |  train_loss 4.1886  |  val_perplexity 249.43
# ────────────────────────────────────────────────────────────
#
#   Epoch 18 | step   300/553 | loss 4.1862
#
# ────────────────────────────────────────────────────────────
# Epoch 18  |  train_loss 4.1869  |  val_perplexity 249.59
# ────────────────────────────────────────────────────────────
#
#   Epoch 19 | step   300/553 | loss 4.1788
#
# ────────────────────────────────────────────────────────────
# Epoch 19  |  train_loss 4.1850  |  val_perplexity 249.66
# ────────────────────────────────────────────────────────────
#
#   Epoch 20 | step   300/553 | loss 4.1709
#
# ────────────────────────────────────────────────────────────
# Epoch 20  |  train_loss 4.1841  |  val_perplexity 249.75
# ────────────────────────────────────────────────────────────
#
#   Epoch 21 | step   300/553 | loss 4.1786
#
# ────────────────────────────────────────────────────────────
# Epoch 21  |  train_loss 4.1830  |  val_perplexity 249.82
# ────────────────────────────────────────────────────────────
#
#   Epoch 22 | step   300/553 | loss 4.1845
#
# ────────────────────────────────────────────────────────────
# Epoch 22  |  train_loss 4.1826  |  val_perplexity 249.89
# ────────────────────────────────────────────────────────────
#
#   Epoch 23 | step   300/553 | loss 4.1665
#
# ────────────────────────────────────────────────────────────
# Epoch 23  |  train_loss 4.1822  |  val_perplexity 249.92
# ────────────────────────────────────────────────────────────
#
#   Epoch 24 | step   300/553 | loss 4.1797
#
# ────────────────────────────────────────────────────────────
# Epoch 24  |  train_loss 4.1817  |  val_perplexity 249.96
# ────────────────────────────────────────────────────────────
#
#   Epoch 25 | step   300/553 | loss 4.1791
#
# ────────────────────────────────────────────────────────────
# Epoch 25  |  train_loss 4.1817  |  val_perplexity 249.97
# ────────────────────────────────────────────────────────────
#
#   Epoch 26 | step   300/553 | loss 4.1839
#
# ────────────────────────────────────────────────────────────
# Epoch 26  |  train_loss 4.1815  |  val_perplexity 250.00
# ────────────────────────────────────────────────────────────
#
#   Epoch 27 | step   300/553 | loss 4.1735
#
# ────────────────────────────────────────────────────────────
# Epoch 27  |  train_loss 4.1813  |  val_perplexity 250.00
# ────────────────────────────────────────────────────────────
#
#   Epoch 28 | step   300/553 | loss 4.1852
#
# ────────────────────────────────────────────────────────────
# Epoch 28  |  train_loss 4.1814  |  val_perplexity 250.01
# ────────────────────────────────────────────────────────────
#
#   Epoch 29 | step   300/553 | loss 4.1820
#
# ────────────────────────────────────────────────────────────
# Epoch 29  |  train_loss 4.1811  |  val_perplexity 250.02
# ────────────────────────────────────────────────────────────
#
#   Epoch 30 | step   300/553 | loss 4.1735
#
# ────────────────────────────────────────────────────────────
# Epoch 30  |  train_loss 4.1811  |  val_perplexity 250.02
# ────────────────────────────────────────────────────────────

# %% [markdown]
# ## 6. Training Curves

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.plot(range(1, EPOCHS+1), train_losses, marker='o', color='steelblue')
ax1.set_title("Training Loss per Epoch (LSTM)")
ax1.set_xlabel("Epoch"); ax1.set_ylabel("Cross-Entropy Loss")
ax1.grid(True, linestyle='--', alpha=0.5)

ax2.plot(range(1, EPOCHS+1), val_perplexities, marker='s', color='darkorange')
ax2.set_title("Validation Perplexity per Epoch (LSTM)")
ax2.set_xlabel("Epoch"); ax2.set_ylabel("Perplexity")
ax2.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.savefig("training_curves_lstm.png", dpi=120)
plt.show()
print("Saved training_curves_lstm.png")
# Out:
# Saved training_curves_lstm.png

# %% [markdown]
# ## 7. Text Generation
#
# We use **temperature-scaled sampling** (T = 0.8):
#
# > $p_i = \frac{e^{z_i / T}}{\sum_j e^{z_j / T}}$
#
# Lower temperature → more conservative; higher → more creative.
#
# > **Note on LSTM generation:** we optionally thread the hidden state
# > `(h, c)` across generation steps, letting the cell accumulate context
# > across the generated tokens — something an Elman RNN could also do,
# > but LSTMs exploit far more effectively thanks to the cell highway.

# %%
def generate(seed_phrase: str, num_words: int = 120, temperature: float = 0.8) -> str:
    model.eval()
    seed_tokens = re.findall(r"[a-z']+", seed_phrase.lower())
    current     = [word2idx.get(t, 0) for t in seed_tokens]

    # Pad / trim to SEQ_LEN
    if len(current) < SEQ_LEN:
        current = [0] * (SEQ_LEN - len(current)) + current
    else:
        current = current[-SEQ_LEN:]

    result = list(seed_tokens)

    # ── Prime the LSTM hidden state on the seed ───────────────
    with torch.no_grad():
        x      = torch.tensor([current], dtype=torch.long, device=device)
        _, hidden = model(x)   # hidden = (h, c)  — carry state forward

        for _ in range(num_words):
            # Feed only the last token; hidden carries the full context
            last   = torch.tensor([[current[-1]]], dtype=torch.long, device=device)
            logits, hidden = model(last, hidden)
            probs  = torch.softmax(logits[0] / temperature, dim=-1)
            next_i = torch.multinomial(probs, 1).item()
            result.append(idx2word.get(next_i, "<UNK>"))
            current = current[1:] + [next_i]

    return " ".join(result)

# %%
seed = "it was a dark and stormy night when the creature appeared"
print(f"Seed: '{seed}'\n")
print("─" * 65)
print(generate(seed, num_words=120, temperature=0.8))
print("─" * 65)
# Out:
# Seed: 'it was a dark and stormy night when the creature appeared'
#
# ─────────────────────────────────────────────────────────────────
# it was a dark and stormy night when the creature appeared to find the practically of people and have took the donate of a corner <UNK> for the project gutenberg license the foundation may be <UNK> from the work of this agreement for a project gutenberg trademark the old project gutenberg website and a temporary project gutenberg website she gave s or <UNK> a parents without project gutenberg electronic works calculated <UNK> for an works or computer a full project gutenberg <UNK> a work is <UNK> or if you not agree agree to see me to the project gutenberg literary archive foundation to how to project gutenberg electronic works they fly requirements to the project gutenberg trademark with the project gutenberg trademark of henry and <UNK> of project gutenberg works i
# ─────────────────────────────────────────────────────────────────

# %%
# Generate with different temperatures to compare
for temp in [0.5, 0.8, 1.2]:
    print(f"\n── Temperature = {temp} ──────────────────────────────────────")
    print(generate("the monster walked through the dark forest", num_words=40, temperature=temp))
# Out:
# ── Temperature = 0.5 ──────────────────────────────────────
# the monster walked through the dark forest check the terms in the united states not <UNK> of the copyright holder you are located in a copyright holder of a work or providing to be a project gutenberg work is a few days of the project gutenberg literary
#
# ── Temperature = 0.8 ──────────────────────────────────────
# the monster walked through the dark forest margin top em and donations project gutenberg electronic project gutenberg ebook or prominently unless ourselves can donate copies new electronic or <UNK> about laws to <UNK> the <UNK> of this agreement you may obtain be you may be <UNK> to
#
# ── Temperature = 1.2 ──────────────────────────────────────
# the monster walked through the dark forest mathematics ligaments leaving roots protected line english city pg country copies text section first found then reverence royalties peculiarly margin body looking to p block conviction met the mountains holder complying most render width appearance fond none we have letter
