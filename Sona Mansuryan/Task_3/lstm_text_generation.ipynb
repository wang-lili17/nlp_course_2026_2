# %% [markdown]
# # **Text Generation with LSTM**

# %% [markdown]
# **1. Import Necessary Libraries**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import requests
from bs4 import BeautifulSoup
import re
import numpy as np
import collections
import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Setting random seeds
torch.manual_seed(42)
np.random.seed(42)
# Out:
# Using device: cuda

# %% [markdown]
# **2. Web Scraping the Data**

# %%
url = "https://www.gutenberg.org/cache/epub/84/pg84-images.html"
print("Downloading text...")
response = requests.get(url)
response.encoding = 'utf-8'

soup = BeautifulSoup(response.text, 'html.parser')
raw_text = soup.get_text()

start_marker = "Letter 1"
end_marker = "THE END"

try:
    start_idx = raw_text.find(start_marker)
    end_idx = raw_text.find(end_marker)
    if start_idx != -1 and end_idx != -1:
        text_data = raw_text[start_idx:end_idx + len(end_marker)]
    else:
        text_data = raw_text
except:
    text_data = raw_text

print(f"Text length: {len(text_data)} characters.")
# Out:
# Downloading text...
# Text length: 446307 characters.

# %% [markdown]
# **3. Data Preprocessing and Tokenization**

# %%
text_data = re.sub(r'([.!?])', r'\1 <END>', text_data)

tokens = re.findall(r"\w+|[^\w\s]|<END>", text_data.lower(), re.UNICODE)
vocab = sorted(list(set(tokens)))
vocab_size = len(vocab)

word_to_idx = {word: i for i, word in enumerate(vocab)}
idx_to_word = {i: word for i, word in enumerate(vocab)}

print(f"Vocabulary Size: {vocab_size}")
# Out:
# Vocabulary Size: 7336

# %% [markdown]
# **4. Preparing Sequences for RNN**

# %%
window_size = 100
seq_length = window_size - 1
inputs = []
targets = []
step = 1

token_indices = [word_to_idx[word] for word in tokens]

for i in range(0, len(token_indices) - window_size, step):
    inputs.append(token_indices[i : i + seq_length])
    targets.append(token_indices[i + seq_length])

print(f"Number of sequences: {len(inputs)}")
# Out:
# Number of sequences: 100382

# %% [markdown]
# **5. Custom Dataset and DataLoader**

# %%
class RNNTextDataset(Dataset):
    def __init__(self, inputs, targets):
        self.inputs = torch.LongTensor(inputs)
        self.targets = torch.LongTensor(targets)

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        return self.inputs[idx], self.targets[idx]

BATCH_SIZE = 64
dataset = RNNTextDataset(inputs, targets)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)

print("DataLoader ready.")
# Out:
# DataLoader ready.

# %% [markdown]
# **6. LSTM Model Implementation**

# %%
class SimpleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, n_layers=2, dropout=0.3):
        super(SimpleLSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(
            embedding_dim, hidden_dim,
            num_layers=n_layers,
            batch_first=True,
            bidirectional=False,
            dropout=dropout if n_layers > 1 else 0
        )
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(hidden_dim)
        self.fc = nn.Linear(hidden_dim, vocab_size)

        total_params = sum(p.numel() for p in self.parameters())
        print(f"[MODEL] LSTM | Params: {total_params:,} | LayerNorm: ✓")

    def forward(self, x, hidden):
        embeds = self.dropout(self.embedding(x))
        out, hidden = self.lstm(embeds, hidden)
        out = self.layer_norm(out[:, -1, :])
        out = self.dropout(out)
        out = self.fc(out)
        return out, hidden

    def init_hidden(self, batch_size):
        h0 = torch.zeros(self.n_layers, batch_size, self.hidden_dim).to(device)
        c0 = torch.zeros(self.n_layers, batch_size, self.hidden_dim).to(device)
        return (h0, c0)

# %% [markdown]
# **7. Hyperparameters and Model Initialization***

# %%
EMBEDDING_DIM  = 256
HIDDEN_DIM     = 768
N_LAYERS       = 2
DROPOUT        = 0.3
LEARNING_RATE  = 0.001
EPOCHS         = 40

model = SimpleLSTM(vocab_size, EMBEDDING_DIM, HIDDEN_DIM, N_LAYERS, DROPOUT).to(device)

def init_weights(m):
    if type(m) == nn.LSTM:
        for name, param in m.named_parameters():
            if 'weight' in name:
                nn.init.orthogonal_(param)
                print(f"  [INIT] Orthogonal → {name}")
    elif type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)
        print(f"  [INIT] Xavier     → Linear layer")

print("[WEIGHT INIT]")
model.apply(init_weights)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
scheduler = optim.lr_scheduler.CosineAnnealingLR(
    optimizer, T_max=EPOCHS, eta_min=1e-5
)

print(f"\n[HYPERPARAMS]")
print(f"  Learning Rate : {LEARNING_RATE}")
print(f"  Epochs        : {EPOCHS}")
print(f"  Batch Size    : {BATCH_SIZE}")
print(f"  Device        : {device}")
# Out:
# [MODEL] LSTM | Params: 15,397,544 | LayerNorm: ✓
# [WEIGHT INIT]
#   [INIT] Orthogonal → weight_ih_l0
#   [INIT] Orthogonal → weight_hh_l0
#   [INIT] Orthogonal → weight_ih_l1
#   [INIT] Orthogonal → weight_hh_l1
#   [INIT] Xavier     → Linear layer
#
# [HYPERPARAMS]
#   Learning Rate : 0.001
#   Epochs        : 40
#   Batch Size    : 64
#   Device        : cuda

# %% [markdown]
# **8. Training Loop**

# %%
def generate_text_gpu(model, seed_text, next_words=100, temperature=1.0, rep_penalty=1.3, greedy=False):
    model.eval()
    words = re.findall(r"\w+|[^\w\s]", seed_text.lower(), re.UNICODE)
    current_seq = [word_to_idx.get(w, 0) for w in words]
    x_in = torch.LongTensor([current_seq]).to(device)
    hidden = model.init_hidden(1)
    generated = words[:]

    with torch.no_grad():
        _, hidden = model(x_in, hidden)
        last_word_idx = current_seq[-1]

        for _ in range(next_words):
            x_in = torch.LongTensor([[last_word_idx]]).to(device)
            output, hidden = model(x_in, hidden)

            logits = output[0] / temperature

            recent_ids = [word_to_idx.get(w, 0) for w in generated[-20:]]
            for prev_id in set(recent_ids):
                logits[prev_id] /= rep_penalty

            if greedy:
                pred_idx = torch.argmax(logits).item()
            else:
                probs = torch.softmax(logits, dim=0).cpu().numpy()
                pred_idx = np.random.choice(len(probs), p=probs)

            pred_word = idx_to_word[pred_idx]

            if pred_word == "<end>":
                break

            generated.append(pred_word)
            last_word_idx = pred_idx

    model.train()
    return " ".join(generated)

# ---- Seed text for samples ----
start_index = random.randint(0, len(tokens) - 150)
seed_text = " ".join(tokens[start_index: start_index + 20])

# ---- Then training loop ----
import time
import math

print(f"{'='*55}")
print(f"  Training started on {device}")
print(f"{'='*55}\n")

best_loss = float('inf')
loss_history = []

for epoch in range(EPOCHS):
    model.train()
    total_loss = 0
    start_time = time.time()

    for batch_idx, (x_batch, y_batch) in enumerate(dataloader):
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)

        hidden = model.init_hidden(BATCH_SIZE)
        hidden = tuple(h.detach() for h in hidden)

        optimizer.zero_grad()

        output, hidden = model(x_batch, hidden)
        loss = criterion(output, y_batch)

        loss.backward()

        # Gradient clipping — 5 → 1 (KEY FIX)
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
        optimizer.step()

        total_loss += loss.item()

        # Batch progress — every 50 batches
        if (batch_idx + 1) % 50 == 0:
            print(f"  [Epoch {epoch+1:02d} | Batch {batch_idx+1:3d}/{len(dataloader)}] "
                  f"Loss: {loss.item():.4f} | GradNorm: {grad_norm:.3f}")

    avg_loss = total_loss / len(dataloader)
    perplexity = math.exp(avg_loss)
    elapsed = time.time() - start_time
    current_lr = optimizer.param_groups[0]['lr']

    loss_history.append(avg_loss)
    scheduler.step()

    # Best model saving
    improved = ""
    if avg_loss < best_loss:
        best_loss = avg_loss
        torch.save(model.state_dict(), 'best_rnn_model.pt')
        improved = "  ✓ Best model saved!"

    print(f"\nEpoch {epoch+1:02d}/{EPOCHS} | "
          f"Loss: {avg_loss:.4f} | "
          f"Perplexity: {perplexity:.1f} | "
          f"LR: {current_lr:.6f} | "
          f"Time: {elapsed:.1f}s"
          f"{improved}\n")

    # Every 5 epochs — generate a sample to see progress
    if (epoch + 1) % 5 == 0:
        print(f"  [SAMPLE at epoch {epoch+1}]")
        sample = generate_text_gpu(model, seed_text, next_words=30, temperature=0.8)
        sample_words = sample.split()
        print("  " + " ".join(sample_words[20:50]))  # only generated part
        print()

print(f"{'='*55}")
print(f"  Training finished! Best loss: {best_loss:.4f}")
print(f"{'='*55}")
# Out:
# =======================================================
#   Training started on cuda
# =======================================================
#
#   [Epoch 01 | Batch  50/1568] Loss: 6.3173 | GradNorm: 4.207
#   [Epoch 01 | Batch 100/1568] Loss: 6.8290 | GradNorm: 4.670
#   [Epoch 01 | Batch 150/1568] Loss: 5.4162 | GradNorm: 4.355
#   [Epoch 01 | Batch 200/1568] Loss: 5.3840 | GradNorm: 4.076
#   [Epoch 01 | Batch 250/1568] Loss: 5.5804 | GradNorm: 3.653
#   [Epoch 01 | Batch 300/1568] Loss: 5.4346 | GradNorm: 3.779
#   [Epoch 01 | Batch 350/1568] Loss: 5.6193 | GradNorm: 3.700
#   [Epoch 01 | Batch 400/1568] Loss: 4.9996 | GradNorm: 3.511
#   [Epoch 01 | Batch 450/1568] Loss: 5.6030 | GradNorm: 3.822
#   [Epoch 01 | Batch 500/1568] Loss: 4.9758 | GradNorm: 3.551
#   [Epoch 01 | Batch 550/1568] Loss: 5.1319 | GradNorm: 3.236
#   [Epoch 01 | Batch 600/1568] Loss: 4.4540 | GradNorm: 3.153
#   [Epoch 01 | Batch 650/1568] Loss: 4.5386 | GradNorm: 3.326
#   [Epoch 01 | Batch 700/1568] Loss: 5.5727 | GradNorm: 3.134
#   [Epoch 01 | Batch 750/1568] Loss: 5.2690 | GradNorm: 3.036
#   [Epoch 01 | Batch 800/1568] Loss: 4.8196 | GradNorm: 2.981
#   [Epoch 01 | Batch 850/1568] Loss: 5.6191 | GradNorm: 2.988
#   [Epoch 01 | Batch 900/1568] Loss: 5.5177 | GradNorm: 3.014
#   [Epoch 01 | Batch 950/1568] Loss: 4.3611 | GradNorm: 2.682
#   [Epoch 01 | Batch 1000/1568] Loss: 4.6297 | GradNorm: 2.753
#   [Epoch 01 | Batch 1050/1568] Loss: 4.7674 | GradNorm: 2.686
#   [Epoch 01 | Batch 1100/1568] Loss: 5.1586 | GradNorm: 2.611
#   [Epoch 01 | Batch 1150/1568] Loss: 4.9510 | GradNorm: 2.445
#   [Epoch 01 | Batch 1200/1568] Loss: 4.7937 | GradNorm: 2.475
#   [Epoch 01 | Batch 1250/1568] Loss: 5.1251 | GradNorm: 2.474
#   [Epoch 01 | Batch 1300/1568] Loss: 5.9746 | GradNorm: 2.604
#   [Epoch 01 | Batch 1350/1568] Loss: 4.9896 | GradNorm: 2.533
#   [Epoch 01 | Batch 1400/1568] Loss: 4.5247 | GradNorm: 2.677
#   [Epoch 01 | Batch 1450/1568] Loss: 4.9088 | GradNorm: 2.346
#   [Epoch 01 | Batch 1500/1568] Loss: 4.3613 | GradNorm: 2.477
#   [Epoch 01 | Batch 1550/1568] Loss: 4.8458 | GradNorm: 2.261
#
# Epoch 01/40 | Loss: 5.2515 | Perplexity: 190.9 | LR: 0.001000 | Time: 49.4s  ✓ Best model saved!
#
#   [Epoch 02 | Batch  50/1568] Loss: 4.9637 | GradNorm: 2.543
#   [Epoch 02 | Batch 100/1568] Loss: 4.7244 | GradNorm: 2.418
#   [Epoch 02 | Batch 150/1568] Loss: 4.8034 | GradNorm: 2.239
#   [Epoch 02 | Batch 200/1568] Loss: 4.3351 | GradNorm: 2.307
#   [Epoch 02 | Batch 250/1568] Loss: 5.1224 | GradNorm: 2.397
#   [Epoch 02 | Batch 300/1568] Loss: 4.7071 | GradNorm: 2.232
#   [Epoch 02 | Batch 350/1568] Loss: 5.0243 | GradNorm: 2.229
#   [Epoch 02 | Batch 400/1568] Loss: 5.4007 | GradNorm: 2.340
#   [Epoch 02 | Batch 450/1568] Loss: 4.8158 | GradNorm: 2.235
#   [Epoch 02 | Batch 500/1568] Loss: 4.7314 | GradNorm: 2.378
#   [Epoch 02 | Batch 550/1568] Loss: 4.2329 | GradNorm: 2.307
#   [Epoch 02 | Batch 600/1568] Loss: 4.7598 | GradNorm: 2.257
#   [Epoch 02 | Batch 650/1568] Loss: 4.8001 | GradNorm: 2.179
#   [Epoch 02 | Batch 700/1568] Loss: 4.5112 | GradNorm: 2.391
#   [Epoch 02 | Batch 750/1568] Loss: 4.9551 | GradNorm: 2.182
#   [Epoch 02 | Batch 800/1568] Loss: 4.0320 | GradNorm: 2.052
#   [Epoch 02 | Batch 850/1568] Loss: 4.5592 | GradNorm: 2.181
#   [Epoch 02 | Batch 900/1568] Loss: 4.0635 | GradNorm: 2.405
#   [Epoch 02 | Batch 950/1568] Loss: 4.6501 | GradNorm: 2.178
#   [Epoch 02 | Batch 1000/1568] Loss: 4.6811 | GradNorm: 2.195
#   [Epoch 02 | Batch 1050/1568] Loss: 4.9219 | GradNorm: 2.188
#   [Epoch 02 | Batch 1100/1568] Loss: 4.8023 | GradNorm: 2.148
#   [Epoch 02 | Batch 1150/1568] Loss: 5.0060 | GradNorm: 2.085
#   [Epoch 02 | Batch 1200/1568] Loss: 5.0869 | GradNorm: 2.267
#   [Epoch 02 | Batch 1250/1568] Loss: 5.2609 | GradNorm: 2.200
#   [Epoch 02 | Batch 1300/1568] Loss: 4.1992 | GradNorm: 2.095
#   [Epoch 02 | Batch 1350/1568] Loss: 4.7563 | GradNorm: 2.073
#   [Epoch 02 | Batch 1400/1568] Loss: 5.0501 | GradNorm: 2.075
#   [Epoch 02 | Batch 1450/1568] Loss: 4.7009 | GradNorm: 2.057
#   [Epoch 02 | Batch 1500/1568] Loss: 4.8207 | GradNorm: 2.040
#   [Epoch 02 | Batch 1550/1568] Loss: 3.6469 | GradNorm: 2.021
#
# Epoch 02/40 | Loss: 4.6480 | Perplexity: 104.4 | LR: 0.000998 | Time: 49.5s  ✓ Best model saved!
#
#   [Epoch 03 | Batch  50/1568] Loss: 4.3752 | GradNorm: 2.188
#   [Epoch 03 | Batch 100/1568] Loss: 4.3434 | GradNorm: 2.067
#   [Epoch 03 | Batch 150/1568] Loss: 5.4228 | GradNorm: 2.279
#   [Epoch 03 | Batch 200/1568] Loss: 4.2829 | GradNorm: 2.363
#   [Epoch 03 | Batch 250/1568] Loss: 4.3039 | GradNorm: 2.428
#   [Epoch 03 | Batch 300/1568] Loss: 3.9360 | GradNorm: 2.315
#   [Epoch 03 | Batch 350/1568] Loss: 3.7525 | GradNorm: 2.077
#   [Epoch 03 | Batch 400/1568] Loss: 3.7726 | GradNorm: 2.191
#   [Epoch 03 | Batch 450/1568] Loss: 4.9838 | GradNorm: 2.376
#   [Epoch 03 | Batch 500/1568] Loss: 4.4019 | GradNorm: 2.250
#   [Epoch 03 | Batch 550/1568] Loss: 4.3363 | GradNorm: 2.355
#   [Epoch 03 | Batch 600/1568] Loss: 3.9403 | GradNorm: 2.028
#   [Epoch 03 | Batch 650/1568] Loss: 4.4359 | GradNorm: 2.221
#   [Epoch 03 | Batch 700/1568] Loss: 4.9738 | GradNorm: 2.283
#   [Epoch 03 | Batch 750/1568] Loss: 4.6391 | GradNorm: 2.276
#   [Epoch 03 | Batch 800/1568] Loss: 4.0337 | GradNorm: 2.245
#   [Epoch 03 | Batch 850/1568] Loss: 4.2803 | GradNorm: 2.241
#   [Epoch 03 | Batch 900/1568] Loss: 4.1989 | GradNorm: 2.170
#   [Epoch 03 | Batch 950/1568] Loss: 4.2549 | GradNorm: 2.178
#   [Epoch 03 | Batch 1000/1568] Loss: 5.0634 | GradNorm: 2.118
#   [Epoch 03 | Batch 1050/1568] Loss: 4.2727 | GradNorm: 2.082
#   [Epoch 03 | Batch 1100/1568] Loss: 4.7178 | GradNorm: 2.102
#   [Epoch 03 | Batch 1150/1568] Loss: 4.5463 | GradNorm: 2.178
#   [Epoch 03 | Batch 1200/1568] Loss: 4.2925 | GradNorm: 2.095
#   [Epoch 03 | Batch 1250/1568] Loss: 4.7350 | GradNorm: 2.123
#   [Epoch 03 | Batch 1300/1568] Loss: 4.8128 | GradNorm: 2.194
#   [Epoch 03 | Batch 1350/1568] Loss: 4.6236 | GradNorm: 2.098
#   [Epoch 03 | Batch 1400/1568] Loss: 4.1135 | GradNorm: 2.004
#   [Epoch 03 | Batch 1450/1568] Loss: 4.4870 | GradNorm: 2.198
#   [Epoch 03 | Batch 1500/1568] Loss: 4.4272 | GradNorm: 2.265
#   [Epoch 03 | Batch 1550/1568] Loss: 4.4173 | GradNorm: 2.020
#
# Epoch 03/40 | Loss: 4.3942 | Perplexity: 81.0 | LR: 0.000994 | Time: 49.4s  ✓ Best model saved!
#
#   [Epoch 04 | Batch  50/1568] Loss: 4.3437 | GradNorm: 2.198
#   [Epoch 04 | Batch 100/1568] Loss: 3.7716 | GradNorm: 2.182
#   [Epoch 04 | Batch 150/1568] Loss: 4.0818 | GradNorm: 2.336
#   [Epoch 04 | Batch 200/1568] Loss: 3.9725 | GradNorm: 2.308
#   [Epoch 04 | Batch 250/1568] Loss: 3.9548 | GradNorm: 2.228
#   [Epoch 04 | Batch 300/1568] Loss: 4.5285 | GradNorm: 2.370
#   [Epoch 04 | Batch 350/1568] Loss: 3.5680 | GradNorm: 2.221
#   [Epoch 04 | Batch 400/1568] Loss: 4.1928 | GradNorm: 2.346
#   [Epoch 04 | Batch 450/1568] Loss: 4.2156 | GradNorm: 2.354
#   [Epoch 04 | Batch 500/1568] Loss: 3.7571 | GradNorm: 2.280
#   [Epoch 04 | Batch 550/1568] Loss: 3.5988 | GradNorm: 2.057
#   [Epoch 04 | Batch 600/1568] Loss: 4.5027 | GradNorm: 2.207
#   [Epoch 04 | Batch 650/1568] Loss: 3.2662 | GradNorm: 2.147
#   [Epoch 04 | Batch 700/1568] Loss: 4.4439 | GradNorm: 2.248
#   [Epoch 04 | Batch 750/1568] Loss: 3.6444 | GradNorm: 2.140
#   [Epoch 04 | Batch 800/1568] Loss: 4.0201 | GradNorm: 2.280
#   [Epoch 04 | Batch 850/1568] Loss: 4.3990 | GradNorm: 2.347
#   [Epoch 04 | Batch 900/1568] Loss: 4.4889 | GradNorm: 2.282
#   [Epoch 04 | Batch 950/1568] Loss: 4.3189 | GradNorm: 2.307
#   [Epoch 04 | Batch 1000/1568] Loss: 4.4668 | GradNorm: 2.281
#   [Epoch 04 | Batch 1050/1568] Loss: 3.9432 | GradNorm: 2.181
#   [Epoch 04 | Batch 1100/1568] Loss: 3.8327 | GradNorm: 2.165
#   [Epoch 04 | Batch 1150/1568] Loss: 4.1648 | GradNorm: 2.273
#   [Epoch 04 | Batch 1200/1568] Loss: 4.4482 | GradNorm: 2.241
#   [Epoch 04 | Batch 1250/1568] Loss: 4.2331 | GradNorm: 2.256
#   [Epoch 04 | Batch 1300/1568] Loss: 4.4186 | GradNorm: 2.238
#   [Epoch 04 | Batch 1350/1568] Loss: 4.2614 | GradNorm: 2.195
#   [Epoch 04 | Batch 1400/1568] Loss: 3.7857 | GradNorm: 2.307
#   [Epoch 04 | Batch 1450/1568] Loss: 4.4149 | GradNorm: 2.168
#   [Epoch 04 | Batch 1500/1568] Loss: 4.3916 | GradNorm: 2.199
#   [Epoch 04 | Batch 1550/1568] Loss: 4.4491 | GradNorm: 2.240
#
# Epoch 04/40 | Loss: 4.1867 | Perplexity: 65.8 | LR: 0.000986 | Time: 49.7s  ✓ Best model saved!
#
#   [Epoch 05 | Batch  50/1568] Loss: 3.3200 | GradNorm: 2.309
#   [Epoch 05 | Batch 100/1568] Loss: 4.1205 | GradNorm: 2.478
#   [Epoch 05 | Batch 150/1568] Loss: 3.7931 | GradNorm: 2.307
#   [Epoch 05 | Batch 200/1568] Loss: 4.3162 | GradNorm: 2.592
#   [Epoch 05 | Batch 250/1568] Loss: 3.6143 | GradNorm: 2.342
#   [Epoch 05 | Batch 300/1568] Loss: 3.2647 | GradNorm: 2.288
#   [Epoch 05 | Batch 350/1568] Loss: 3.9872 | GradNorm: 2.500
#   [Epoch 05 | Batch 400/1568] Loss: 4.2828 | GradNorm: 2.462
#   [Epoch 05 | Batch 450/1568] Loss: 3.7911 | GradNorm: 2.369
#   [Epoch 05 | Batch 500/1568] Loss: 3.7909 | GradNorm: 2.326
#   [Epoch 05 | Batch 550/1568] Loss: 3.3956 | GradNorm: 2.376
#   [Epoch 05 | Batch 600/1568] Loss: 3.8310 | GradNorm: 2.536
#   [Epoch 05 | Batch 650/1568] Loss: 4.1024 | GradNorm: 2.479
#   [Epoch 05 | Batch 700/1568] Loss: 4.3713 | GradNorm: 2.498
#   [Epoch 05 | Batch 750/1568] Loss: 4.6938 | GradNorm: 2.514
#   [Epoch 05 | Batch 800/1568] Loss: 3.9834 | GradNorm: 2.482
#   [Epoch 05 | Batch 850/1568] Loss: 4.1128 | GradNorm: 2.350
#   [Epoch 05 | Batch 900/1568] Loss: 4.2122 | GradNorm: 2.503
#   [Epoch 05 | Batch 950/1568] Loss: 4.0217 | GradNorm: 2.264
#   [Epoch 05 | Batch 1000/1568] Loss: 3.9178 | GradNorm: 2.357
#   [Epoch 05 | Batch 1050/1568] Loss: 4.3026 | GradNorm: 2.490
#   [Epoch 05 | Batch 1100/1568] Loss: 3.5910 | GradNorm: 2.260
#   [Epoch 05 | Batch 1150/1568] Loss: 4.4384 | GradNorm: 2.549
#   [Epoch 05 | Batch 1200/1568] Loss: 4.3723 | GradNorm: 2.449
#   [Epoch 05 | Batch 1250/1568] Loss: 4.1367 | GradNorm: 2.363
#   [Epoch 05 | Batch 1300/1568] Loss: 4.2506 | GradNorm: 2.344
#   [Epoch 05 | Batch 1350/1568] Loss: 3.9023 | GradNorm: 2.368
#   [Epoch 05 | Batch 1400/1568] Loss: 4.0274 | GradNorm: 2.225
#   [Epoch 05 | Batch 1450/1568] Loss: 3.6126 | GradNorm: 2.239
#   [Epoch 05 | Batch 1500/1568] Loss: 4.2101 | GradNorm: 2.304
#   [Epoch 05 | Batch 1550/1568] Loss: 4.4520 | GradNorm: 2.430
#
# Epoch 05/40 | Loss: 4.0037 | Perplexity: 54.8 | LR: 0.000976 | Time: 50.1s  ✓ Best model saved!
#
#   [SAMPLE at epoch 5]
#   fulfil with their memory . < end > i saw a wish to commence me , but now partly in my determination a hopes of the creation and opprobrium -
#
#   [Epoch 06 | Batch  50/1568] Loss: 3.7627 | GradNorm: 2.474
#   [Epoch 06 | Batch 100/1568] Loss: 3.4443 | GradNorm: 2.473
#   [Epoch 06 | Batch 150/1568] Loss: 3.2481 | GradNorm: 2.443
#   [Epoch 06 | Batch 200/1568] Loss: 4.1256 | GradNorm: 2.609
#   [Epoch 06 | Batch 250/1568] Loss: 4.4016 | GradNorm: 2.783
#   [Epoch 06 | Batch 300/1568] Loss: 3.3830 | GradNorm: 2.483
#   [Epoch 06 | Batch 350/1568] Loss: 3.6084 | GradNorm: 2.628
#   [Epoch 06 | Batch 400/1568] Loss: 3.8058 | GradNorm: 2.482
#   [Epoch 06 | Batch 450/1568] Loss: 3.7868 | GradNorm: 2.624
#   [Epoch 06 | Batch 500/1568] Loss: 3.9235 | GradNorm: 2.737
#   [Epoch 06 | Batch 550/1568] Loss: 4.1237 | GradNorm: 2.589
#   [Epoch 06 | Batch 600/1568] Loss: 3.9734 | GradNorm: 2.681
#   [Epoch 06 | Batch 650/1568] Loss: 3.6172 | GradNorm: 2.639
#   [Epoch 06 | Batch 700/1568] Loss: 4.2012 | GradNorm: 2.759
#   [Epoch 06 | Batch 750/1568] Loss: 3.6425 | GradNorm: 2.668
#   [Epoch 06 | Batch 800/1568] Loss: 3.4351 | GradNorm: 2.526
#   [Epoch 06 | Batch 850/1568] Loss: 3.6917 | GradNorm: 2.613
#   [Epoch 06 | Batch 900/1568] Loss: 3.9886 | GradNorm: 2.531
#   [Epoch 06 | Batch 950/1568] Loss: 4.4537 | GradNorm: 2.685
#   [Epoch 06 | Batch 1000/1568] Loss: 3.9879 | GradNorm: 2.530
#   [Epoch 06 | Batch 1050/1568] Loss: 3.4917 | GradNorm: 2.595
#   [Epoch 06 | Batch 1100/1568] Loss: 3.7643 | GradNorm: 2.601
#   [Epoch 06 | Batch 1150/1568] Loss: 3.8203 | GradNorm: 2.469
#   [Epoch 06 | Batch 1200/1568] Loss: 4.0748 | GradNorm: 2.647
#   [Epoch 06 | Batch 1250/1568] Loss: 3.9562 | GradNorm: 2.469
#   [Epoch 06 | Batch 1300/1568] Loss: 3.7335 | GradNorm: 2.449
#   [Epoch 06 | Batch 1350/1568] Loss: 3.8573 | GradNorm: 2.449
#   [Epoch 06 | Batch 1400/1568] Loss: 3.1820 | GradNorm: 2.460
#   [Epoch 06 | Batch 1450/1568] Loss: 4.2670 | GradNorm: 2.642
#   [Epoch 06 | Batch 1500/1568] Loss: 4.5260 | GradNorm: 2.685
#   [Epoch 06 | Batch 1550/1568] Loss: 4.5053 | GradNorm: 2.664
#
# Epoch 06/40 | Loss: 3.8260 | Perplexity: 45.9 | LR: 0.000962 | Time: 51.5s  ✓ Best model saved!
#
#   [Epoch 07 | Batch  50/1568] Loss: 3.7129 | GradNorm: 2.716
#   [Epoch 07 | Batch 100/1568] Loss: 3.1654 | GradNorm: 2.653
#   [Epoch 07 | Batch 150/1568] Loss: 3.9502 | GradNorm: 3.060
#   [Epoch 07 | Batch 200/1568] Loss: 4.3262 | GradNorm: 3.054
#   [Epoch 07 | Batch 250/1568] Loss: 2.9326 | GradNorm: 2.648
#   [Epoch 07 | Batch 300/1568] Loss: 3.4216 | GradNorm: 2.780
#   [Epoch 07 | Batch 350/1568] Loss: 3.3762 | GradNorm: 2.821
#   [Epoch 07 | Batch 400/1568] Loss: 3.4898 | GradNorm: 2.795
#   [Epoch 07 | Batch 450/1568] Loss: 3.5658 | GradNorm: 2.819
#   [Epoch 07 | Batch 500/1568] Loss: 3.4849 | GradNorm: 2.720
#   [Epoch 07 | Batch 550/1568] Loss: 3.5969 | GradNorm: 2.882
#   [Epoch 07 | Batch 600/1568] Loss: 3.2668 | GradNorm: 2.797
#   [Epoch 07 | Batch 650/1568] Loss: 3.7060 | GradNorm: 3.049
#   [Epoch 07 | Batch 700/1568] Loss: 3.7117 | GradNorm: 2.829
#   [Epoch 07 | Batch 750/1568] Loss: 3.7122 | GradNorm: 2.954
#   [Epoch 07 | Batch 800/1568] Loss: 3.4630 | GradNorm: 2.764
#   [Epoch 07 | Batch 850/1568] Loss: 3.9908 | GradNorm: 2.801
#   [Epoch 07 | Batch 900/1568] Loss: 3.6513 | GradNorm: 2.716
#   [Epoch 07 | Batch 950/1568] Loss: 3.9101 | GradNorm: 2.909
#   [Epoch 07 | Batch 1000/1568] Loss: 3.6553 | GradNorm: 2.894
#   [Epoch 07 | Batch 1050/1568] Loss: 4.1550 | GradNorm: 3.023
#   [Epoch 07 | Batch 1100/1568] Loss: 3.7324 | GradNorm: 2.689
#   [Epoch 07 | Batch 1150/1568] Loss: 3.7701 | GradNorm: 2.806
#   [Epoch 07 | Batch 1200/1568] Loss: 4.2628 | GradNorm: 3.170
#   [Epoch 07 | Batch 1250/1568] Loss: 4.2425 | GradNorm: 2.919
#   [Epoch 07 | Batch 1300/1568] Loss: 3.7356 | GradNorm: 2.683
#   [Epoch 07 | Batch 1350/1568] Loss: 4.1372 | GradNorm: 2.776
#   [Epoch 07 | Batch 1400/1568] Loss: 3.3241 | GradNorm: 2.659
#   [Epoch 07 | Batch 1450/1568] Loss: 3.7175 | GradNorm: 2.679
#   [Epoch 07 | Batch 1500/1568] Loss: 3.6635 | GradNorm: 2.697
#   [Epoch 07 | Batch 1550/1568] Loss: 4.3112 | GradNorm: 2.767
#
# Epoch 07/40 | Loss: 3.6435 | Perplexity: 38.2 | LR: 0.000946 | Time: 50.1s  ✓ Best model saved!
#
#   [Epoch 08 | Batch  50/1568] Loss: 3.1265 | GradNorm: 2.879
#   [Epoch 08 | Batch 100/1568] Loss: 2.9391 | GradNorm: 2.776
#   [Epoch 08 | Batch 150/1568] Loss: 2.7918 | GradNorm: 2.770
#   [Epoch 08 | Batch 200/1568] Loss: 2.9246 | GradNorm: 2.828
#   [Epoch 08 | Batch 250/1568] Loss: 2.5041 | GradNorm: 2.769
#   [Epoch 08 | Batch 300/1568] Loss: 3.1154 | GradNorm: 2.937
#   [Epoch 08 | Batch 350/1568] Loss: 3.7245 | GradNorm: 3.186
#   [Epoch 08 | Batch 400/1568] Loss: 3.1949 | GradNorm: 2.979
#   [Epoch 08 | Batch 450/1568] Loss: 3.6146 | GradNorm: 3.092
#   [Epoch 08 | Batch 500/1568] Loss: 3.3873 | GradNorm: 3.067
#   [Epoch 08 | Batch 550/1568] Loss: 3.3348 | GradNorm: 2.950
#   [Epoch 08 | Batch 600/1568] Loss: 3.2628 | GradNorm: 2.977
#   [Epoch 08 | Batch 650/1568] Loss: 3.7219 | GradNorm: 2.996
#   [Epoch 08 | Batch 700/1568] Loss: 3.0256 | GradNorm: 2.991
#   [Epoch 08 | Batch 750/1568] Loss: 3.1841 | GradNorm: 2.783
#   [Epoch 08 | Batch 800/1568] Loss: 3.4967 | GradNorm: 3.011
#   [Epoch 08 | Batch 850/1568] Loss: 3.1769 | GradNorm: 3.034
#   [Epoch 08 | Batch 900/1568] Loss: 3.7385 | GradNorm: 3.119
#   [Epoch 08 | Batch 950/1568] Loss: 3.9709 | GradNorm: 3.132
#   [Epoch 08 | Batch 1000/1568] Loss: 3.3277 | GradNorm: 3.076
#   [Epoch 08 | Batch 1050/1568] Loss: 3.9861 | GradNorm: 3.154
#   [Epoch 08 | Batch 1100/1568] Loss: 3.4149 | GradNorm: 2.985
#   [Epoch 08 | Batch 1150/1568] Loss: 3.5351 | GradNorm: 3.009
#   [Epoch 08 | Batch 1200/1568] Loss: 3.9905 | GradNorm: 3.011
#   [Epoch 08 | Batch 1250/1568] Loss: 2.8968 | GradNorm: 2.862
#   [Epoch 08 | Batch 1300/1568] Loss: 3.7969 | GradNorm: 3.096
#   [Epoch 08 | Batch 1350/1568] Loss: 3.4206 | GradNorm: 2.970
#   [Epoch 08 | Batch 1400/1568] Loss: 4.4679 | GradNorm: 3.273
#   [Epoch 08 | Batch 1450/1568] Loss: 3.5482 | GradNorm: 2.840
#   [Epoch 08 | Batch 1500/1568] Loss: 3.5597 | GradNorm: 2.943
#   [Epoch 08 | Batch 1550/1568] Loss: 4.3197 | GradNorm: 3.088
#
# Epoch 08/40 | Loss: 3.4542 | Perplexity: 31.6 | LR: 0.000927 | Time: 50.1s  ✓ Best model saved!
#
#   [Epoch 09 | Batch  50/1568] Loss: 2.8300 | GradNorm: 2.949
#   [Epoch 09 | Batch 100/1568] Loss: 2.8224 | GradNorm: 3.094
#   [Epoch 09 | Batch 150/1568] Loss: 3.3038 | GradNorm: 3.120
#   [Epoch 09 | Batch 200/1568] Loss: 3.1734 | GradNorm: 3.220
#   [Epoch 09 | Batch 250/1568] Loss: 3.5067 | GradNorm: 3.257
#   [Epoch 09 | Batch 300/1568] Loss: 2.6763 | GradNorm: 2.884
#   [Epoch 09 | Batch 350/1568] Loss: 3.5362 | GradNorm: 3.247
#   [Epoch 09 | Batch 400/1568] Loss: 3.2555 | GradNorm: 3.145
#   [Epoch 09 | Batch 450/1568] Loss: 3.3547 | GradNorm: 3.361
#   [Epoch 09 | Batch 500/1568] Loss: 2.2690 | GradNorm: 2.906
#   [Epoch 09 | Batch 550/1568] Loss: 2.9442 | GradNorm: 3.318
#   [Epoch 09 | Batch 600/1568] Loss: 2.9529 | GradNorm: 3.201
#   [Epoch 09 | Batch 650/1568] Loss: 3.5934 | GradNorm: 3.352
#   [Epoch 09 | Batch 700/1568] Loss: 3.7478 | GradNorm: 3.372
#   [Epoch 09 | Batch 750/1568] Loss: 3.4032 | GradNorm: 3.372
#   [Epoch 09 | Batch 800/1568] Loss: 3.5226 | GradNorm: 3.299
#   [Epoch 09 | Batch 850/1568] Loss: 3.1370 | GradNorm: 3.320
#   [Epoch 09 | Batch 900/1568] Loss: 3.8677 | GradNorm: 3.380
#   [Epoch 09 | Batch 950/1568] Loss: 3.5641 | GradNorm: 3.332
#   [Epoch 09 | Batch 1000/1568] Loss: 3.2300 | GradNorm: 3.220
#   [Epoch 09 | Batch 1050/1568] Loss: 3.2136 | GradNorm: 3.092
#   [Epoch 09 | Batch 1100/1568] Loss: 3.7059 | GradNorm: 3.502
#   [Epoch 09 | Batch 1150/1568] Loss: 3.5819 | GradNorm: 3.524
#   [Epoch 09 | Batch 1200/1568] Loss: 3.4605 | GradNorm: 3.302
#   [Epoch 09 | Batch 1250/1568] Loss: 3.5469 | GradNorm: 3.296
#   [Epoch 09 | Batch 1300/1568] Loss: 3.7278 | GradNorm: 3.251
#   [Epoch 09 | Batch 1350/1568] Loss: 3.2371 | GradNorm: 3.276
#   [Epoch 09 | Batch 1400/1568] Loss: 4.1353 | GradNorm: 3.247
#   [Epoch 09 | Batch 1450/1568] Loss: 3.5385 | GradNorm: 3.145
#   [Epoch 09 | Batch 1500/1568] Loss: 3.5506 | GradNorm: 3.224
#   [Epoch 09 | Batch 1550/1568] Loss: 3.4281 | GradNorm: 3.165
#
# Epoch 09/40 | Loss: 3.2599 | Perplexity: 26.0 | LR: 0.000905 | Time: 50.5s  ✓ Best model saved!
#
#   [Epoch 10 | Batch  50/1568] Loss: 2.0631 | GradNorm: 2.876
#   [Epoch 10 | Batch 100/1568] Loss: 2.9022 | GradNorm: 3.390
#   [Epoch 10 | Batch 150/1568] Loss: 2.9124 | GradNorm: 3.384
#   [Epoch 10 | Batch 200/1568] Loss: 2.8097 | GradNorm: 3.175
#   [Epoch 10 | Batch 250/1568] Loss: 2.8288 | GradNorm: 3.238
#   [Epoch 10 | Batch 300/1568] Loss: 2.7359 | GradNorm: 3.441
#   [Epoch 10 | Batch 350/1568] Loss: 2.6112 | GradNorm: 3.240
#   [Epoch 10 | Batch 400/1568] Loss: 2.9407 | GradNorm: 3.340
#   [Epoch 10 | Batch 450/1568] Loss: 2.6796 | GradNorm: 3.261
#   [Epoch 10 | Batch 500/1568] Loss: 3.3885 | GradNorm: 3.392
#   [Epoch 10 | Batch 550/1568] Loss: 2.6550 | GradNorm: 3.308
#   [Epoch 10 | Batch 600/1568] Loss: 3.1766 | GradNorm: 3.396
#   [Epoch 10 | Batch 650/1568] Loss: 3.2032 | GradNorm: 3.575
#   [Epoch 10 | Batch 700/1568] Loss: 3.1585 | GradNorm: 3.600
#   [Epoch 10 | Batch 750/1568] Loss: 2.9918 | GradNorm: 3.481
#   [Epoch 10 | Batch 800/1568] Loss: 2.7369 | GradNorm: 3.359
#   [Epoch 10 | Batch 850/1568] Loss: 3.0257 | GradNorm: 3.450
#   [Epoch 10 | Batch 900/1568] Loss: 3.3430 | GradNorm: 3.332
#   [Epoch 10 | Batch 950/1568] Loss: 3.6360 | GradNorm: 3.703
#   [Epoch 10 | Batch 1000/1568] Loss: 3.1994 | GradNorm: 3.502
#   [Epoch 10 | Batch 1050/1568] Loss: 3.1526 | GradNorm: 3.455
#   [Epoch 10 | Batch 1100/1568] Loss: 3.2476 | GradNorm: 3.395
#   [Epoch 10 | Batch 1150/1568] Loss: 3.1569 | GradNorm: 3.543
#   [Epoch 10 | Batch 1200/1568] Loss: 2.9370 | GradNorm: 3.269
#   [Epoch 10 | Batch 1250/1568] Loss: 3.0555 | GradNorm: 3.488
#   [Epoch 10 | Batch 1300/1568] Loss: 3.2711 | GradNorm: 3.336
#   [Epoch 10 | Batch 1350/1568] Loss: 3.5622 | GradNorm: 3.490
#   [Epoch 10 | Batch 1400/1568] Loss: 3.2378 | GradNorm: 3.519
#   [Epoch 10 | Batch 1450/1568] Loss: 3.3025 | GradNorm: 3.490
#   [Epoch 10 | Batch 1500/1568] Loss: 3.6385 | GradNorm: 3.493
#   [Epoch 10 | Batch 1550/1568] Loss: 3.2789 | GradNorm: 3.435
#
# Epoch 10/40 | Loss: 3.0610 | Perplexity: 21.3 | LR: 0.000881 | Time: 49.6s  ✓ Best model saved!
#
#   [SAMPLE at epoch 10]
#   me . < end > yet i am not imperatively , for far two years have elapsed since the day that was visible on my ruin . < end >
#
#   [Epoch 11 | Batch  50/1568] Loss: 2.8620 | GradNorm: 3.504
#   [Epoch 11 | Batch 100/1568] Loss: 1.9667 | GradNorm: 3.434
#   [Epoch 11 | Batch 150/1568] Loss: 2.4314 | GradNorm: 3.390
#   [Epoch 11 | Batch 200/1568] Loss: 2.7708 | GradNorm: 3.501
#   [Epoch 11 | Batch 250/1568] Loss: 2.8690 | GradNorm: 3.672
#   [Epoch 11 | Batch 300/1568] Loss: 2.2013 | GradNorm: 3.276
#   [Epoch 11 | Batch 350/1568] Loss: 2.5066 | GradNorm: 3.607
#   [Epoch 11 | Batch 400/1568] Loss: 2.2993 | GradNorm: 3.324
#   [Epoch 11 | Batch 450/1568] Loss: 3.1230 | GradNorm: 3.701
#   [Epoch 11 | Batch 500/1568] Loss: 2.7779 | GradNorm: 3.660
#   [Epoch 11 | Batch 550/1568] Loss: 2.5409 | GradNorm: 3.572
#   [Epoch 11 | Batch 600/1568] Loss: 2.7593 | GradNorm: 3.680
#   [Epoch 11 | Batch 650/1568] Loss: 2.4910 | GradNorm: 3.599
#   [Epoch 11 | Batch 700/1568] Loss: 2.5673 | GradNorm: 3.618
#   [Epoch 11 | Batch 750/1568] Loss: 3.3081 | GradNorm: 3.844
#   [Epoch 11 | Batch 800/1568] Loss: 3.0508 | GradNorm: 3.760
#   [Epoch 11 | Batch 850/1568] Loss: 3.3426 | GradNorm: 3.930
#   [Epoch 11 | Batch 900/1568] Loss: 3.0439 | GradNorm: 3.846
#   [Epoch 11 | Batch 950/1568] Loss: 2.7847 | GradNorm: 3.776
#   [Epoch 11 | Batch 1000/1568] Loss: 2.9592 | GradNorm: 3.836
#   [Epoch 11 | Batch 1050/1568] Loss: 2.9432 | GradNorm: 3.890
#   [Epoch 11 | Batch 1100/1568] Loss: 2.4854 | GradNorm: 3.640
#   [Epoch 11 | Batch 1150/1568] Loss: 3.1348 | GradNorm: 3.768
#   [Epoch 11 | Batch 1200/1568] Loss: 3.1783 | GradNorm: 3.960
#   [Epoch 11 | Batch 1250/1568] Loss: 2.9423 | GradNorm: 3.765
#   [Epoch 11 | Batch 1300/1568] Loss: 3.3516 | GradNorm: 3.777
#   [Epoch 11 | Batch 1350/1568] Loss: 3.1273 | GradNorm: 3.664
#   [Epoch 11 | Batch 1400/1568] Loss: 3.6144 | GradNorm: 3.787
#   [Epoch 11 | Batch 1450/1568] Loss: 3.5357 | GradNorm: 3.894
#   [Epoch 11 | Batch 1500/1568] Loss: 3.5204 | GradNorm: 3.724
#   [Epoch 11 | Batch 1550/1568] Loss: 2.6484 | GradNorm: 3.407
#
# Epoch 11/40 | Loss: 2.8492 | Perplexity: 17.3 | LR: 0.000855 | Time: 84.5s  ✓ Best model saved!
#
#   [Epoch 12 | Batch  50/1568] Loss: 2.1998 | GradNorm: 3.505
#   [Epoch 12 | Batch 100/1568] Loss: 2.1147 | GradNorm: 3.387
#   [Epoch 12 | Batch 150/1568] Loss: 2.4647 | GradNorm: 3.867
#   [Epoch 12 | Batch 200/1568] Loss: 2.4870 | GradNorm: 3.484
#   [Epoch 12 | Batch 250/1568] Loss: 2.0864 | GradNorm: 3.574
#   [Epoch 12 | Batch 300/1568] Loss: 2.3929 | GradNorm: 3.807
#   [Epoch 12 | Batch 350/1568] Loss: 2.7392 | GradNorm: 3.731
#   [Epoch 12 | Batch 400/1568] Loss: 2.5683 | GradNorm: 3.975
#   [Epoch 12 | Batch 450/1568] Loss: 2.5856 | GradNorm: 3.937
#   [Epoch 12 | Batch 500/1568] Loss: 3.0690 | GradNorm: 4.149
#   [Epoch 12 | Batch 550/1568] Loss: 2.3789 | GradNorm: 3.825
#   [Epoch 12 | Batch 600/1568] Loss: 2.2828 | GradNorm: 3.484
#   [Epoch 12 | Batch 650/1568] Loss: 2.7785 | GradNorm: 3.826
#   [Epoch 12 | Batch 700/1568] Loss: 2.9198 | GradNorm: 3.907
#   [Epoch 12 | Batch 750/1568] Loss: 2.6229 | GradNorm: 3.920
#   [Epoch 12 | Batch 800/1568] Loss: 2.9845 | GradNorm: 4.125
#   [Epoch 12 | Batch 850/1568] Loss: 2.8789 | GradNorm: 3.956
#   [Epoch 12 | Batch 900/1568] Loss: 2.8816 | GradNorm: 4.172
#   [Epoch 12 | Batch 950/1568] Loss: 2.6097 | GradNorm: 3.704
#   [Epoch 12 | Batch 1000/1568] Loss: 3.2196 | GradNorm: 4.180
#   [Epoch 12 | Batch 1050/1568] Loss: 2.7370 | GradNorm: 3.658
#   [Epoch 12 | Batch 1100/1568] Loss: 3.1730 | GradNorm: 4.122
#   [Epoch 12 | Batch 1150/1568] Loss: 2.9910 | GradNorm: 4.159
#   [Epoch 12 | Batch 1200/1568] Loss: 2.5995 | GradNorm: 3.691
#   [Epoch 12 | Batch 1250/1568] Loss: 2.8127 | GradNorm: 3.799
#   [Epoch 12 | Batch 1300/1568] Loss: 2.2966 | GradNorm: 3.634
#   [Epoch 12 | Batch 1350/1568] Loss: 2.8693 | GradNorm: 4.072
#   [Epoch 12 | Batch 1400/1568] Loss: 2.7809 | GradNorm: 3.803
#   [Epoch 12 | Batch 1450/1568] Loss: 2.6091 | GradNorm: 3.817
#   [Epoch 12 | Batch 1500/1568] Loss: 2.8925 | GradNorm: 4.110
#   [Epoch 12 | Batch 1550/1568] Loss: 2.5070 | GradNorm: 3.819
#
# Epoch 12/40 | Loss: 2.6637 | Perplexity: 14.3 | LR: 0.000826 | Time: 51.6s  ✓ Best model saved!
#
#   [Epoch 13 | Batch  50/1568] Loss: 1.8218 | GradNorm: 3.370
#   [Epoch 13 | Batch 100/1568] Loss: 2.3313 | GradNorm: 3.639
#   [Epoch 13 | Batch 150/1568] Loss: 2.1027 | GradNorm: 3.702
#   [Epoch 13 | Batch 200/1568] Loss: 2.0094 | GradNorm: 3.752
#   [Epoch 13 | Batch 250/1568] Loss: 1.9718 | GradNorm: 3.700
#   [Epoch 13 | Batch 300/1568] Loss: 1.9524 | GradNorm: 3.676
#   [Epoch 13 | Batch 350/1568] Loss: 2.1511 | GradNorm: 3.908
#   [Epoch 13 | Batch 400/1568] Loss: 2.5583 | GradNorm: 3.741
#   [Epoch 13 | Batch 450/1568] Loss: 2.2055 | GradNorm: 4.008
#   [Epoch 13 | Batch 500/1568] Loss: 2.9779 | GradNorm: 4.405
#   [Epoch 13 | Batch 550/1568] Loss: 2.2811 | GradNorm: 4.127
#   [Epoch 13 | Batch 600/1568] Loss: 2.5256 | GradNorm: 4.169
#   [Epoch 13 | Batch 650/1568] Loss: 2.3417 | GradNorm: 3.982
#   [Epoch 13 | Batch 700/1568] Loss: 2.3420 | GradNorm: 4.179
#   [Epoch 13 | Batch 750/1568] Loss: 2.8300 | GradNorm: 4.176
#   [Epoch 13 | Batch 800/1568] Loss: 2.4810 | GradNorm: 4.265
#   [Epoch 13 | Batch 850/1568] Loss: 3.0082 | GradNorm: 3.939
#   [Epoch 13 | Batch 900/1568] Loss: 2.7807 | GradNorm: 4.270
#   [Epoch 13 | Batch 950/1568] Loss: 2.6148 | GradNorm: 4.126
#   [Epoch 13 | Batch 1000/1568] Loss: 2.0843 | GradNorm: 3.826
#   [Epoch 13 | Batch 1050/1568] Loss: 2.6966 | GradNorm: 4.237
#   [Epoch 13 | Batch 1100/1568] Loss: 2.7365 | GradNorm: 4.052
#   [Epoch 13 | Batch 1150/1568] Loss: 2.1913 | GradNorm: 3.720
#   [Epoch 13 | Batch 1200/1568] Loss: 2.9360 | GradNorm: 4.104
#   [Epoch 13 | Batch 1250/1568] Loss: 2.5829 | GradNorm: 3.772
#   [Epoch 13 | Batch 1300/1568] Loss: 2.5219 | GradNorm: 3.855
#   [Epoch 13 | Batch 1350/1568] Loss: 2.7142 | GradNorm: 4.102
#   [Epoch 13 | Batch 1400/1568] Loss: 2.7839 | GradNorm: 3.961
#   [Epoch 13 | Batch 1450/1568] Loss: 2.3940 | GradNorm: 3.979
#   [Epoch 13 | Batch 1500/1568] Loss: 2.4686 | GradNorm: 3.999
#   [Epoch 13 | Batch 1550/1568] Loss: 2.4247 | GradNorm: 4.057
#
# Epoch 13/40 | Loss: 2.4643 | Perplexity: 11.8 | LR: 0.000796 | Time: 52.2s  ✓ Best model saved!
#
#   [Epoch 14 | Batch  50/1568] Loss: 1.6241 | GradNorm: 3.531
#   [Epoch 14 | Batch 100/1568] Loss: 1.4776 | GradNorm: 3.407
#   [Epoch 14 | Batch 150/1568] Loss: 1.6104 | GradNorm: 3.666
#   [Epoch 14 | Batch 200/1568] Loss: 1.8719 | GradNorm: 3.839
#   [Epoch 14 | Batch 250/1568] Loss: 1.8182 | GradNorm: 3.664
#   [Epoch 14 | Batch 300/1568] Loss: 1.4954 | GradNorm: 3.637
#   [Epoch 14 | Batch 350/1568] Loss: 2.1657 | GradNorm: 4.186
#   [Epoch 14 | Batch 400/1568] Loss: 2.5922 | GradNorm: 4.035
#   [Epoch 14 | Batch 450/1568] Loss: 1.7869 | GradNorm: 3.867
#   [Epoch 14 | Batch 500/1568] Loss: 2.2685 | GradNorm: 4.145
#   [Epoch 14 | Batch 550/1568] Loss: 1.9267 | GradNorm: 3.773
#   [Epoch 14 | Batch 600/1568] Loss: 2.5659 | GradNorm: 4.205
#   [Epoch 14 | Batch 650/1568] Loss: 2.1658 | GradNorm: 4.047
#   [Epoch 14 | Batch 700/1568] Loss: 2.2815 | GradNorm: 3.970
#   [Epoch 14 | Batch 750/1568] Loss: 2.2905 | GradNorm: 4.002
#   [Epoch 14 | Batch 800/1568] Loss: 2.4708 | GradNorm: 4.608
#   [Epoch 14 | Batch 850/1568] Loss: 2.3917 | GradNorm: 4.254
#   [Epoch 14 | Batch 900/1568] Loss: 2.1750 | GradNorm: 4.116
#   [Epoch 14 | Batch 950/1568] Loss: 2.2806 | GradNorm: 4.169
#   [Epoch 14 | Batch 1000/1568] Loss: 2.2914 | GradNorm: 4.084
#   [Epoch 14 | Batch 1050/1568] Loss: 2.5714 | GradNorm: 4.340
#   [Epoch 14 | Batch 1100/1568] Loss: 2.2541 | GradNorm: 4.147
#   [Epoch 14 | Batch 1150/1568] Loss: 2.6808 | GradNorm: 4.458
#   [Epoch 14 | Batch 1200/1568] Loss: 2.7319 | GradNorm: 4.173
#   [Epoch 14 | Batch 1250/1568] Loss: 2.4544 | GradNorm: 4.351
#   [Epoch 14 | Batch 1300/1568] Loss: 2.3307 | GradNorm: 3.987
#   [Epoch 14 | Batch 1350/1568] Loss: 2.7323 | GradNorm: 4.362
#   [Epoch 14 | Batch 1400/1568] Loss: 2.4044 | GradNorm: 4.463
#   [Epoch 14 | Batch 1450/1568] Loss: 2.6448 | GradNorm: 4.206
#   [Epoch 14 | Batch 1500/1568] Loss: 2.6306 | GradNorm: 4.266
#   [Epoch 14 | Batch 1550/1568] Loss: 2.3980 | GradNorm: 4.292
#
# Epoch 14/40 | Loss: 2.2939 | Perplexity: 9.9 | LR: 0.000764 | Time: 51.0s  ✓ Best model saved!
#
#   [Epoch 15 | Batch  50/1568] Loss: 1.7435 | GradNorm: 3.674
#   [Epoch 15 | Batch 100/1568] Loss: 1.5941 | GradNorm: 3.530
#   [Epoch 15 | Batch 150/1568] Loss: 1.4046 | GradNorm: 3.634
#   [Epoch 15 | Batch 200/1568] Loss: 1.7885 | GradNorm: 4.105
#   [Epoch 15 | Batch 250/1568] Loss: 1.6105 | GradNorm: 3.814
#   [Epoch 15 | Batch 300/1568] Loss: 1.9944 | GradNorm: 4.157
#   [Epoch 15 | Batch 350/1568] Loss: 1.8575 | GradNorm: 4.011
#   [Epoch 15 | Batch 400/1568] Loss: 2.4518 | GradNorm: 4.482
#   [Epoch 15 | Batch 450/1568] Loss: 1.5659 | GradNorm: 3.941
#   [Epoch 15 | Batch 500/1568] Loss: 1.7402 | GradNorm: 4.088
#   [Epoch 15 | Batch 550/1568] Loss: 2.1330 | GradNorm: 3.983
#   [Epoch 15 | Batch 600/1568] Loss: 2.0120 | GradNorm: 3.888
#   [Epoch 15 | Batch 650/1568] Loss: 1.7770 | GradNorm: 4.032
#   [Epoch 15 | Batch 700/1568] Loss: 1.7651 | GradNorm: 4.072
#   [Epoch 15 | Batch 750/1568] Loss: 2.5858 | GradNorm: 4.209
#   [Epoch 15 | Batch 800/1568] Loss: 1.6515 | GradNorm: 3.695
#   [Epoch 15 | Batch 850/1568] Loss: 2.0087 | GradNorm: 3.804
#   [Epoch 15 | Batch 900/1568] Loss: 2.2844 | GradNorm: 4.508
#   [Epoch 15 | Batch 950/1568] Loss: 2.5884 | GradNorm: 4.452
#   [Epoch 15 | Batch 1000/1568] Loss: 1.9425 | GradNorm: 3.996
#   [Epoch 15 | Batch 1050/1568] Loss: 2.2627 | GradNorm: 4.176
#   [Epoch 15 | Batch 1100/1568] Loss: 2.4319 | GradNorm: 4.479
#   [Epoch 15 | Batch 1150/1568] Loss: 2.0788 | GradNorm: 4.086
#   [Epoch 15 | Batch 1200/1568] Loss: 2.3729 | GradNorm: 4.234
#   [Epoch 15 | Batch 1250/1568] Loss: 1.9666 | GradNorm: 4.148
#   [Epoch 15 | Batch 1300/1568] Loss: 2.0991 | GradNorm: 3.965
#   [Epoch 15 | Batch 1350/1568] Loss: 2.5532 | GradNorm: 4.318
#   [Epoch 15 | Batch 1400/1568] Loss: 2.0887 | GradNorm: 4.353
#   [Epoch 15 | Batch 1450/1568] Loss: 2.5886 | GradNorm: 4.645
#   [Epoch 15 | Batch 1500/1568] Loss: 2.1609 | GradNorm: 4.394
#   [Epoch 15 | Batch 1550/1568] Loss: 2.3803 | GradNorm: 4.270
#
# Epoch 15/40 | Loss: 2.1317 | Perplexity: 8.4 | LR: 0.000730 | Time: 52.2s  ✓ Best model saved!
#
#   [SAMPLE at epoch 15]
#   ear interpretation our lives as i dun . < end > even any words shall he not ; but at the murderer ’ s grasp , it is the same
#
#   [Epoch 16 | Batch  50/1568] Loss: 1.2560 | GradNorm: 3.606
#   [Epoch 16 | Batch 100/1568] Loss: 1.4463 | GradNorm: 3.700
#   [Epoch 16 | Batch 150/1568] Loss: 2.3794 | GradNorm: 4.284
#   [Epoch 16 | Batch 200/1568] Loss: 1.9090 | GradNorm: 4.221
#   [Epoch 16 | Batch 250/1568] Loss: 1.5774 | GradNorm: 3.690
#   [Epoch 16 | Batch 300/1568] Loss: 1.3196 | GradNorm: 3.904
#   [Epoch 16 | Batch 350/1568] Loss: 1.7723 | GradNorm: 3.868
#   [Epoch 16 | Batch 400/1568] Loss: 1.8056 | GradNorm: 4.116
#   [Epoch 16 | Batch 450/1568] Loss: 1.6259 | GradNorm: 3.883
#   [Epoch 16 | Batch 500/1568] Loss: 1.7092 | GradNorm: 3.948
#   [Epoch 16 | Batch 550/1568] Loss: 1.6713 | GradNorm: 4.251
#   [Epoch 16 | Batch 600/1568] Loss: 1.8708 | GradNorm: 4.341
#   [Epoch 16 | Batch 650/1568] Loss: 2.4529 | GradNorm: 4.494
#   [Epoch 16 | Batch 700/1568] Loss: 1.6985 | GradNorm: 4.235
#   [Epoch 16 | Batch 750/1568] Loss: 1.9778 | GradNorm: 4.163
#   [Epoch 16 | Batch 800/1568] Loss: 2.0739 | GradNorm: 4.756
#   [Epoch 16 | Batch 850/1568] Loss: 2.1829 | GradNorm: 4.455
#   [Epoch 16 | Batch 900/1568] Loss: 1.7358 | GradNorm: 4.163
#   [Epoch 16 | Batch 950/1568] Loss: 2.1380 | GradNorm: 4.626
#   [Epoch 16 | Batch 1000/1568] Loss: 1.8253 | GradNorm: 4.190
#   [Epoch 16 | Batch 1050/1568] Loss: 1.7780 | GradNorm: 4.439
#   [Epoch 16 | Batch 1100/1568] Loss: 2.0442 | GradNorm: 4.482
#   [Epoch 16 | Batch 1150/1568] Loss: 1.8439 | GradNorm: 4.295
#   [Epoch 16 | Batch 1200/1568] Loss: 2.2507 | GradNorm: 4.480
#   [Epoch 16 | Batch 1250/1568] Loss: 2.2470 | GradNorm: 4.746
#   [Epoch 16 | Batch 1300/1568] Loss: 2.2368 | GradNorm: 4.156
#   [Epoch 16 | Batch 1350/1568] Loss: 2.1309 | GradNorm: 4.683
#   [Epoch 16 | Batch 1400/1568] Loss: 2.2355 | GradNorm: 4.503
#   [Epoch 16 | Batch 1450/1568] Loss: 2.5175 | GradNorm: 4.766
#   [Epoch 16 | Batch 1500/1568] Loss: 2.2186 | GradNorm: 4.622
#   [Epoch 16 | Batch 1550/1568] Loss: 2.1855 | GradNorm: 4.439
#
# Epoch 16/40 | Loss: 1.9907 | Perplexity: 7.3 | LR: 0.000694 | Time: 51.2s  ✓ Best model saved!
#
#   [Epoch 17 | Batch  50/1568] Loss: 1.5252 | GradNorm: 3.765
#   [Epoch 17 | Batch 100/1568] Loss: 1.2468 | GradNorm: 3.746
#   [Epoch 17 | Batch 150/1568] Loss: 1.6006 | GradNorm: 4.295
#   [Epoch 17 | Batch 200/1568] Loss: 1.4648 | GradNorm: 3.912
#   [Epoch 17 | Batch 250/1568] Loss: 1.5979 | GradNorm: 4.065
#   [Epoch 17 | Batch 300/1568] Loss: 1.3778 | GradNorm: 4.036
#   [Epoch 17 | Batch 350/1568] Loss: 1.9946 | GradNorm: 4.733
#   [Epoch 17 | Batch 400/1568] Loss: 1.6304 | GradNorm: 4.274
#   [Epoch 17 | Batch 450/1568] Loss: 2.1545 | GradNorm: 4.570
#   [Epoch 17 | Batch 500/1568] Loss: 1.9874 | GradNorm: 4.447
#   [Epoch 17 | Batch 550/1568] Loss: 1.6006 | GradNorm: 4.294
#   [Epoch 17 | Batch 600/1568] Loss: 1.5852 | GradNorm: 4.040
#   [Epoch 17 | Batch 650/1568] Loss: 1.6081 | GradNorm: 4.090
#   [Epoch 17 | Batch 700/1568] Loss: 1.5378 | GradNorm: 4.051
#   [Epoch 17 | Batch 750/1568] Loss: 1.9104 | GradNorm: 4.675
#   [Epoch 17 | Batch 800/1568] Loss: 1.4374 | GradNorm: 3.776
#   [Epoch 17 | Batch 850/1568] Loss: 2.4253 | GradNorm: 5.036
#   [Epoch 17 | Batch 900/1568] Loss: 2.2833 | GradNorm: 4.775
#   [Epoch 17 | Batch 950/1568] Loss: 1.5508 | GradNorm: 3.940
#   [Epoch 17 | Batch 1000/1568] Loss: 1.7503 | GradNorm: 4.370
#   [Epoch 17 | Batch 1050/1568] Loss: 1.7566 | GradNorm: 4.408
#   [Epoch 17 | Batch 1100/1568] Loss: 1.7411 | GradNorm: 4.534
#   [Epoch 17 | Batch 1150/1568] Loss: 2.2658 | GradNorm: 4.806
#   [Epoch 17 | Batch 1200/1568] Loss: 2.0230 | GradNorm: 4.544
#   [Epoch 17 | Batch 1250/1568] Loss: 2.1531 | GradNorm: 4.830
#   [Epoch 17 | Batch 1300/1568] Loss: 1.8274 | GradNorm: 4.510
#   [Epoch 17 | Batch 1350/1568] Loss: 2.4215 | GradNorm: 5.084
#   [Epoch 17 | Batch 1400/1568] Loss: 2.3947 | GradNorm: 4.782
#   [Epoch 17 | Batch 1450/1568] Loss: 2.4833 | GradNorm: 5.133
#   [Epoch 17 | Batch 1500/1568] Loss: 1.7786 | GradNorm: 4.425
#   [Epoch 17 | Batch 1550/1568] Loss: 2.7802 | GradNorm: 5.142
#
# Epoch 17/40 | Loss: 1.8646 | Perplexity: 6.5 | LR: 0.000658 | Time: 51.1s  ✓ Best model saved!
#
#   [Epoch 18 | Batch  50/1568] Loss: 1.3316 | GradNorm: 3.801
#   [Epoch 18 | Batch 100/1568] Loss: 1.0982 | GradNorm: 3.871
#   [Epoch 18 | Batch 150/1568] Loss: 1.4444 | GradNorm: 4.023
#   [Epoch 18 | Batch 200/1568] Loss: 1.4412 | GradNorm: 4.053
#   [Epoch 18 | Batch 250/1568] Loss: 1.4025 | GradNorm: 3.788
#   [Epoch 18 | Batch 300/1568] Loss: 1.3210 | GradNorm: 4.053
#   [Epoch 18 | Batch 350/1568] Loss: 1.3793 | GradNorm: 4.267
#   [Epoch 18 | Batch 400/1568] Loss: 1.5083 | GradNorm: 4.097
#   [Epoch 18 | Batch 450/1568] Loss: 1.7917 | GradNorm: 4.457
#   [Epoch 18 | Batch 500/1568] Loss: 1.3656 | GradNorm: 4.070
#   [Epoch 18 | Batch 550/1568] Loss: 1.5864 | GradNorm: 4.219
#   [Epoch 18 | Batch 600/1568] Loss: 1.6600 | GradNorm: 4.497
#   [Epoch 18 | Batch 650/1568] Loss: 1.7263 | GradNorm: 4.280
#   [Epoch 18 | Batch 700/1568] Loss: 1.7067 | GradNorm: 4.380
#   [Epoch 18 | Batch 750/1568] Loss: 1.6418 | GradNorm: 4.565
#   [Epoch 18 | Batch 800/1568] Loss: 2.1065 | GradNorm: 4.985
#   [Epoch 18 | Batch 850/1568] Loss: 1.5352 | GradNorm: 4.568
#   [Epoch 18 | Batch 900/1568] Loss: 2.1302 | GradNorm: 4.826
#   [Epoch 18 | Batch 950/1568] Loss: 1.5394 | GradNorm: 4.058
#   [Epoch 18 | Batch 1000/1568] Loss: 1.7496 | GradNorm: 4.589
#   [Epoch 18 | Batch 1050/1568] Loss: 2.0047 | GradNorm: 4.769
#   [Epoch 18 | Batch 1100/1568] Loss: 2.0049 | GradNorm: 4.333
#   [Epoch 18 | Batch 1150/1568] Loss: 2.3691 | GradNorm: 4.802
#   [Epoch 18 | Batch 1200/1568] Loss: 1.9694 | GradNorm: 4.865
#   [Epoch 18 | Batch 1250/1568] Loss: 2.3058 | GradNorm: 4.877
#   [Epoch 18 | Batch 1300/1568] Loss: 2.1097 | GradNorm: 4.482
#   [Epoch 18 | Batch 1350/1568] Loss: 1.9804 | GradNorm: 4.915
#   [Epoch 18 | Batch 1400/1568] Loss: 1.6256 | GradNorm: 4.228
#   [Epoch 18 | Batch 1450/1568] Loss: 1.7734 | GradNorm: 4.462
#   [Epoch 18 | Batch 1500/1568] Loss: 2.0967 | GradNorm: 4.636
#   [Epoch 18 | Batch 1550/1568] Loss: 2.1689 | GradNorm: 4.603
#
# Epoch 18/40 | Loss: 1.7322 | Perplexity: 5.7 | LR: 0.000621 | Time: 51.3s  ✓ Best model saved!
#
#   [Epoch 19 | Batch  50/1568] Loss: 1.3633 | GradNorm: 3.882
#   [Epoch 19 | Batch 100/1568] Loss: 1.2962 | GradNorm: 3.982
#   [Epoch 19 | Batch 150/1568] Loss: 1.1937 | GradNorm: 3.948
#   [Epoch 19 | Batch 200/1568] Loss: 1.4499 | GradNorm: 4.371
#   [Epoch 19 | Batch 250/1568] Loss: 1.3082 | GradNorm: 4.060
#   [Epoch 19 | Batch 300/1568] Loss: 1.4251 | GradNorm: 4.252
#   [Epoch 19 | Batch 350/1568] Loss: 1.4060 | GradNorm: 3.955
#   [Epoch 19 | Batch 400/1568] Loss: 1.3042 | GradNorm: 3.920
#   [Epoch 19 | Batch 450/1568] Loss: 1.6853 | GradNorm: 4.197
#   [Epoch 19 | Batch 500/1568] Loss: 1.2183 | GradNorm: 4.122
#   [Epoch 19 | Batch 550/1568] Loss: 1.5840 | GradNorm: 4.413
#   [Epoch 19 | Batch 600/1568] Loss: 1.3343 | GradNorm: 4.569
#   [Epoch 19 | Batch 650/1568] Loss: 1.7008 | GradNorm: 4.466
#   [Epoch 19 | Batch 700/1568] Loss: 1.4949 | GradNorm: 4.335
#   [Epoch 19 | Batch 750/1568] Loss: 1.9182 | GradNorm: 5.051
#   [Epoch 19 | Batch 800/1568] Loss: 1.4023 | GradNorm: 4.378
#   [Epoch 19 | Batch 850/1568] Loss: 1.7044 | GradNorm: 4.779
#   [Epoch 19 | Batch 900/1568] Loss: 1.7943 | GradNorm: 4.551
#   [Epoch 19 | Batch 950/1568] Loss: 1.9224 | GradNorm: 4.704
#   [Epoch 19 | Batch 1000/1568] Loss: 2.1175 | GradNorm: 5.031
#   [Epoch 19 | Batch 1050/1568] Loss: 1.6507 | GradNorm: 4.631
#   [Epoch 19 | Batch 1100/1568] Loss: 2.0036 | GradNorm: 5.017
#   [Epoch 19 | Batch 1150/1568] Loss: 1.7408 | GradNorm: 4.769
#   [Epoch 19 | Batch 1200/1568] Loss: 1.7133 | GradNorm: 4.793
#   [Epoch 19 | Batch 1250/1568] Loss: 1.9747 | GradNorm: 4.590
#   [Epoch 19 | Batch 1300/1568] Loss: 2.0998 | GradNorm: 5.258
#   [Epoch 19 | Batch 1350/1568] Loss: 1.6921 | GradNorm: 4.401
#   [Epoch 19 | Batch 1400/1568] Loss: 1.9946 | GradNorm: 5.123
#   [Epoch 19 | Batch 1450/1568] Loss: 1.9807 | GradNorm: 4.654
#   [Epoch 19 | Batch 1500/1568] Loss: 2.2488 | GradNorm: 5.163
#   [Epoch 19 | Batch 1550/1568] Loss: 2.0664 | GradNorm: 5.021
#
# Epoch 19/40 | Loss: 1.6282 | Perplexity: 5.1 | LR: 0.000582 | Time: 50.5s  ✓ Best model saved!
#
#   [Epoch 20 | Batch  50/1568] Loss: 1.2219 | GradNorm: 3.882
#   [Epoch 20 | Batch 100/1568] Loss: 0.9162 | GradNorm: 3.590
#   [Epoch 20 | Batch 150/1568] Loss: 1.2995 | GradNorm: 4.207
#   [Epoch 20 | Batch 200/1568] Loss: 1.1472 | GradNorm: 3.951
#   [Epoch 20 | Batch 250/1568] Loss: 1.5889 | GradNorm: 4.377
#   [Epoch 20 | Batch 300/1568] Loss: 1.1337 | GradNorm: 4.133
#   [Epoch 20 | Batch 350/1568] Loss: 1.4951 | GradNorm: 4.408
#   [Epoch 20 | Batch 400/1568] Loss: 1.4320 | GradNorm: 4.317
#   [Epoch 20 | Batch 450/1568] Loss: 1.4570 | GradNorm: 4.342
#   [Epoch 20 | Batch 500/1568] Loss: 1.1649 | GradNorm: 4.063
#   [Epoch 20 | Batch 550/1568] Loss: 1.0969 | GradNorm: 4.086
#   [Epoch 20 | Batch 600/1568] Loss: 1.0988 | GradNorm: 4.269
#   [Epoch 20 | Batch 650/1568] Loss: 1.6140 | GradNorm: 4.685
#   [Epoch 20 | Batch 700/1568] Loss: 1.8518 | GradNorm: 5.303
#   [Epoch 20 | Batch 750/1568] Loss: 1.6557 | GradNorm: 4.818
#   [Epoch 20 | Batch 800/1568] Loss: 1.5227 | GradNorm: 4.565
#   [Epoch 20 | Batch 850/1568] Loss: 1.5602 | GradNorm: 4.812
#   [Epoch 20 | Batch 900/1568] Loss: 1.8949 | GradNorm: 4.933
#   [Epoch 20 | Batch 950/1568] Loss: 2.0657 | GradNorm: 5.074
#   [Epoch 20 | Batch 1000/1568] Loss: 1.6338 | GradNorm: 4.970
#   [Epoch 20 | Batch 1050/1568] Loss: 1.6191 | GradNorm: 4.710
#   [Epoch 20 | Batch 1100/1568] Loss: 1.5562 | GradNorm: 4.695
#   [Epoch 20 | Batch 1150/1568] Loss: 1.4467 | GradNorm: 4.436
#   [Epoch 20 | Batch 1200/1568] Loss: 2.0130 | GradNorm: 5.061
#   [Epoch 20 | Batch 1250/1568] Loss: 1.9551 | GradNorm: 5.036
#   [Epoch 20 | Batch 1300/1568] Loss: 1.7246 | GradNorm: 4.998
#   [Epoch 20 | Batch 1350/1568] Loss: 1.7563 | GradNorm: 4.841
#   [Epoch 20 | Batch 1400/1568] Loss: 1.8277 | GradNorm: 5.044
#   [Epoch 20 | Batch 1450/1568] Loss: 1.7737 | GradNorm: 4.808
#   [Epoch 20 | Batch 1500/1568] Loss: 2.2154 | GradNorm: 5.168
#   [Epoch 20 | Batch 1550/1568] Loss: 1.7451 | GradNorm: 4.963
#
# Epoch 20/40 | Loss: 1.5200 | Perplexity: 4.6 | LR: 0.000544 | Time: 50.9s  ✓ Best model saved!
#
#   [SAMPLE at epoch 20]
#   be present from you . < end > but i am not mad , very full of land and discrimination both ; yet when the reality was considered that that
#
#   [Epoch 21 | Batch  50/1568] Loss: 1.2284 | GradNorm: 4.328
#   [Epoch 21 | Batch 100/1568] Loss: 1.1614 | GradNorm: 4.143
#   [Epoch 21 | Batch 150/1568] Loss: 1.0150 | GradNorm: 4.316
#   [Epoch 21 | Batch 200/1568] Loss: 1.2837 | GradNorm: 4.421
#   [Epoch 21 | Batch 250/1568] Loss: 1.1924 | GradNorm: 4.407
#   [Epoch 21 | Batch 300/1568] Loss: 1.1498 | GradNorm: 3.921
#   [Epoch 21 | Batch 350/1568] Loss: 1.3101 | GradNorm: 4.576
#   [Epoch 21 | Batch 400/1568] Loss: 1.2880 | GradNorm: 4.160
#   [Epoch 21 | Batch 450/1568] Loss: 0.9874 | GradNorm: 3.918
#   [Epoch 21 | Batch 500/1568] Loss: 1.1226 | GradNorm: 4.405
#   [Epoch 21 | Batch 550/1568] Loss: 1.2573 | GradNorm: 4.651
#   [Epoch 21 | Batch 600/1568] Loss: 1.5507 | GradNorm: 4.546
#   [Epoch 21 | Batch 650/1568] Loss: 1.4473 | GradNorm: 4.601
#   [Epoch 21 | Batch 700/1568] Loss: 1.3387 | GradNorm: 4.521
#   [Epoch 21 | Batch 750/1568] Loss: 1.3127 | GradNorm: 4.548
#   [Epoch 21 | Batch 800/1568] Loss: 1.4227 | GradNorm: 4.528
#   [Epoch 21 | Batch 850/1568] Loss: 1.4961 | GradNorm: 4.697
#   [Epoch 21 | Batch 900/1568] Loss: 1.4517 | GradNorm: 4.520
#   [Epoch 21 | Batch 950/1568] Loss: 1.5931 | GradNorm: 4.795
#   [Epoch 21 | Batch 1000/1568] Loss: 1.3206 | GradNorm: 4.518
#   [Epoch 21 | Batch 1050/1568] Loss: 1.4315 | GradNorm: 4.520
#   [Epoch 21 | Batch 1100/1568] Loss: 1.6053 | GradNorm: 4.905
#   [Epoch 21 | Batch 1150/1568] Loss: 1.2211 | GradNorm: 4.387
#   [Epoch 21 | Batch 1200/1568] Loss: 1.5782 | GradNorm: 4.746
#   [Epoch 21 | Batch 1250/1568] Loss: 1.5720 | GradNorm: 4.695
#   [Epoch 21 | Batch 1300/1568] Loss: 1.3213 | GradNorm: 4.629
#   [Epoch 21 | Batch 1350/1568] Loss: 1.7664 | GradNorm: 5.131
#   [Epoch 21 | Batch 1400/1568] Loss: 1.3172 | GradNorm: 4.628
#   [Epoch 21 | Batch 1450/1568] Loss: 1.5865 | GradNorm: 4.691
#   [Epoch 21 | Batch 1500/1568] Loss: 1.7901 | GradNorm: 5.096
#   [Epoch 21 | Batch 1550/1568] Loss: 1.9509 | GradNorm: 5.493
#
# Epoch 21/40 | Loss: 1.4240 | Perplexity: 4.2 | LR: 0.000505 | Time: 51.3s  ✓ Best model saved!
#
#   [Epoch 22 | Batch  50/1568] Loss: 0.8116 | GradNorm: 3.666
#   [Epoch 22 | Batch 100/1568] Loss: 1.1378 | GradNorm: 3.982
#   [Epoch 22 | Batch 150/1568] Loss: 1.3544 | GradNorm: 4.698
#   [Epoch 22 | Batch 200/1568] Loss: 1.0222 | GradNorm: 4.066
#   [Epoch 22 | Batch 250/1568] Loss: 0.9936 | GradNorm: 4.202
#   [Epoch 22 | Batch 300/1568] Loss: 1.0706 | GradNorm: 4.149
#   [Epoch 22 | Batch 350/1568] Loss: 0.8765 | GradNorm: 3.758
#   [Epoch 22 | Batch 400/1568] Loss: 1.0770 | GradNorm: 4.264
#   [Epoch 22 | Batch 450/1568] Loss: 1.2442 | GradNorm: 4.347
#   [Epoch 22 | Batch 500/1568] Loss: 1.3647 | GradNorm: 4.913
#   [Epoch 22 | Batch 550/1568] Loss: 1.5219 | GradNorm: 4.955
#   [Epoch 22 | Batch 600/1568] Loss: 1.0322 | GradNorm: 4.399
#   [Epoch 22 | Batch 650/1568] Loss: 1.0414 | GradNorm: 4.284
#   [Epoch 22 | Batch 700/1568] Loss: 1.0514 | GradNorm: 4.123
#   [Epoch 22 | Batch 750/1568] Loss: 1.3677 | GradNorm: 4.715
#   [Epoch 22 | Batch 800/1568] Loss: 1.0624 | GradNorm: 4.477
#   [Epoch 22 | Batch 850/1568] Loss: 1.3348 | GradNorm: 4.447
#   [Epoch 22 | Batch 900/1568] Loss: 1.2756 | GradNorm: 4.779
#   [Epoch 22 | Batch 950/1568] Loss: 1.0588 | GradNorm: 4.449
#   [Epoch 22 | Batch 1000/1568] Loss: 1.3814 | GradNorm: 4.482
#   [Epoch 22 | Batch 1050/1568] Loss: 1.3390 | GradNorm: 4.639
#   [Epoch 22 | Batch 1100/1568] Loss: 1.2427 | GradNorm: 4.663
#   [Epoch 22 | Batch 1150/1568] Loss: 1.2657 | GradNorm: 4.760
#   [Epoch 22 | Batch 1200/1568] Loss: 1.2415 | GradNorm: 4.360
#   [Epoch 22 | Batch 1250/1568] Loss: 1.3272 | GradNorm: 4.507
#   [Epoch 22 | Batch 1300/1568] Loss: 1.7714 | GradNorm: 5.382
#   [Epoch 22 | Batch 1350/1568] Loss: 1.8428 | GradNorm: 5.043
#   [Epoch 22 | Batch 1400/1568] Loss: 1.5574 | GradNorm: 4.958
#   [Epoch 22 | Batch 1450/1568] Loss: 1.5249 | GradNorm: 4.725
#   [Epoch 22 | Batch 1500/1568] Loss: 1.6850 | GradNorm: 5.323
#   [Epoch 22 | Batch 1550/1568] Loss: 1.8314 | GradNorm: 5.301
#
# Epoch 22/40 | Loss: 1.3247 | Perplexity: 3.8 | LR: 0.000466 | Time: 50.7s  ✓ Best model saved!
#
#   [Epoch 23 | Batch  50/1568] Loss: 0.8650 | GradNorm: 3.884
#   [Epoch 23 | Batch 100/1568] Loss: 0.9629 | GradNorm: 3.928
#   [Epoch 23 | Batch 150/1568] Loss: 1.0333 | GradNorm: 4.133
#   [Epoch 23 | Batch 200/1568] Loss: 1.1022 | GradNorm: 4.538
#   [Epoch 23 | Batch 250/1568] Loss: 1.0739 | GradNorm: 4.401
#   [Epoch 23 | Batch 300/1568] Loss: 1.0834 | GradNorm: 4.410
#   [Epoch 23 | Batch 350/1568] Loss: 1.0663 | GradNorm: 4.436
#   [Epoch 23 | Batch 400/1568] Loss: 1.0266 | GradNorm: 4.362
#   [Epoch 23 | Batch 450/1568] Loss: 1.0323 | GradNorm: 4.318
#   [Epoch 23 | Batch 500/1568] Loss: 1.2420 | GradNorm: 4.796
#   [Epoch 23 | Batch 550/1568] Loss: 1.2895 | GradNorm: 4.823
#   [Epoch 23 | Batch 600/1568] Loss: 1.0985 | GradNorm: 4.168
#   [Epoch 23 | Batch 650/1568] Loss: 1.3720 | GradNorm: 4.633
#   [Epoch 23 | Batch 700/1568] Loss: 1.6593 | GradNorm: 5.235
#   [Epoch 23 | Batch 750/1568] Loss: 1.3166 | GradNorm: 4.640
#   [Epoch 23 | Batch 800/1568] Loss: 1.5097 | GradNorm: 5.093
#   [Epoch 23 | Batch 850/1568] Loss: 1.2529 | GradNorm: 4.496
#   [Epoch 23 | Batch 900/1568] Loss: 0.8639 | GradNorm: 3.915
#   [Epoch 23 | Batch 950/1568] Loss: 1.5493 | GradNorm: 5.199
#   [Epoch 23 | Batch 1000/1568] Loss: 1.3726 | GradNorm: 4.874
#   [Epoch 23 | Batch 1050/1568] Loss: 1.4187 | GradNorm: 4.889
#   [Epoch 23 | Batch 1100/1568] Loss: 1.3435 | GradNorm: 4.647
#   [Epoch 23 | Batch 1150/1568] Loss: 1.3655 | GradNorm: 4.838
#   [Epoch 23 | Batch 1200/1568] Loss: 1.0519 | GradNorm: 4.401
#   [Epoch 23 | Batch 1250/1568] Loss: 1.7559 | GradNorm: 5.525
#   [Epoch 23 | Batch 1300/1568] Loss: 1.2891 | GradNorm: 4.743
#   [Epoch 23 | Batch 1350/1568] Loss: 1.4004 | GradNorm: 4.984
#   [Epoch 23 | Batch 1400/1568] Loss: 1.1866 | GradNorm: 4.606
#   [Epoch 23 | Batch 1450/1568] Loss: 1.2964 | GradNorm: 5.138
#   [Epoch 23 | Batch 1500/1568] Loss: 1.6851 | GradNorm: 5.541
#   [Epoch 23 | Batch 1550/1568] Loss: 1.3990 | GradNorm: 5.249
#
# Epoch 23/40 | Loss: 1.2325 | Perplexity: 3.4 | LR: 0.000428 | Time: 51.8s  ✓ Best model saved!
#
#   [Epoch 24 | Batch  50/1568] Loss: 1.0574 | GradNorm: 4.225
#   [Epoch 24 | Batch 100/1568] Loss: 0.7894 | GradNorm: 3.937
#   [Epoch 24 | Batch 150/1568] Loss: 0.9631 | GradNorm: 3.947
#   [Epoch 24 | Batch 200/1568] Loss: 0.9635 | GradNorm: 4.280
#   [Epoch 24 | Batch 250/1568] Loss: 1.3701 | GradNorm: 4.740
#   [Epoch 24 | Batch 300/1568] Loss: 0.8071 | GradNorm: 3.941
#   [Epoch 24 | Batch 350/1568] Loss: 0.8945 | GradNorm: 4.087
#   [Epoch 24 | Batch 400/1568] Loss: 0.8348 | GradNorm: 3.778
#   [Epoch 24 | Batch 450/1568] Loss: 1.0695 | GradNorm: 4.793
#   [Epoch 24 | Batch 500/1568] Loss: 0.9732 | GradNorm: 4.268
#   [Epoch 24 | Batch 550/1568] Loss: 1.0178 | GradNorm: 4.733
#   [Epoch 24 | Batch 600/1568] Loss: 0.9746 | GradNorm: 4.365
#   [Epoch 24 | Batch 650/1568] Loss: 1.1954 | GradNorm: 4.788
#   [Epoch 24 | Batch 700/1568] Loss: 1.4728 | GradNorm: 5.084
#   [Epoch 24 | Batch 750/1568] Loss: 1.2889 | GradNorm: 4.566
#   [Epoch 24 | Batch 800/1568] Loss: 1.4390 | GradNorm: 4.846
#   [Epoch 24 | Batch 850/1568] Loss: 1.2417 | GradNorm: 4.817
#   [Epoch 24 | Batch 900/1568] Loss: 0.9843 | GradNorm: 4.328
#   [Epoch 24 | Batch 950/1568] Loss: 1.4613 | GradNorm: 4.890
# ...
#   [Epoch 33 | Batch 450/1568] Loss: 0.4982 | GradNorm: 3.586
#   [Epoch 33 | Batch 500/1568] Loss: 0.5082 | GradNorm: 3.761
#   [Epoch 33 | Batch 550/1568] Loss: 0.3833 | GradNorm: 3.240
#   [Epoch 33 | Batch 600/1568] Loss: 0.7930 | GradNorm: 4.959
#   [Epoch 33 | Batch 650/1568] Loss: 0.4808 | GradNorm: 3.639
#   [Epoch 33 | Batch 700/1568] Loss: 0.8571 | GradNorm: 5.349
#   [Epoch 33 | Batch 750/1568] Loss: 0.5884 | GradNorm: 4.399
#   [Epoch 33 | Batch 800/1568] Loss: 0.5545 | GradNorm: 4.083
#   [Epoch 33 | Batch 850/1568] Loss: 0.6039 | GradNorm: 4.339
#   [Epoch 33 | Batch 900/1568] Loss: 0.7498 | GradNorm: 4.312
#   [Epoch 33 | Batch 950/1568] Loss: 0.8446 | GradNorm: 4.902
#   [Epoch 33 | Batch 1000/1568] Loss: 0.6709 | GradNorm: 4.551
#   [Epoch 33 | Batch 1050/1568] Loss: 0.6973 | GradNorm: 4.328
#   [Epoch 33 | Batch 1100/1568] Loss: 0.5760 | GradNorm: 4.223
#   [Epoch 33 | Batch 1150/1568] Loss: 0.8379 | GradNorm: 5.092
#   [Epoch 33 | Batch 1200/1568] Loss: 0.6378 | GradNorm: 4.571
#   [Epoch 33 | Batch 1250/1568] Loss: 0.6997 | GradNorm: 4.747
#   [Epoch 33 | Batch 1300/1568] Loss: 0.6682 | GradNorm: 4.531
#   [Epoch 33 | Batch 1350/1568] Loss: 0.5132 | GradNorm: 4.045
#   [Epoch 33 | Batch 1400/1568] Loss: 0.7948 | GradNorm: 4.950
#   [Epoch 33 | Batch 1450/1568] Loss: 0.6416 | GradNorm: 4.156
#   [Epoch 33 | Batch 1500/1568] Loss: 0.6223 | GradNorm: 4.470
#   [Epoch 33 | Batch 1550/1568] Loss: 0.8143 | GradNorm: 4.884
#
# Epoch 33/40 | Loss: 0.6184 | Perplexity: 1.9 | LR: 0.000105 | Time: 51.8s  ✓ Best model saved!
#
#   [Epoch 34 | Batch  50/1568] Loss: 0.4280 | GradNorm: 3.684
#   [Epoch 34 | Batch 100/1568] Loss: 0.5936 | GradNorm: 4.527
#   [Epoch 34 | Batch 150/1568] Loss: 0.4842 | GradNorm: 3.784
#   [Epoch 34 | Batch 200/1568] Loss: 0.3647 | GradNorm: 3.428
#   [Epoch 34 | Batch 250/1568] Loss: 0.6267 | GradNorm: 4.089
#   [Epoch 34 | Batch 300/1568] Loss: 0.6905 | GradNorm: 4.711
#   [Epoch 34 | Batch 350/1568] Loss: 0.5025 | GradNorm: 4.131
#   [Epoch 34 | Batch 400/1568] Loss: 0.4343 | GradNorm: 3.853
#   [Epoch 34 | Batch 450/1568] Loss: 0.8530 | GradNorm: 4.945
#   [Epoch 34 | Batch 500/1568] Loss: 0.3908 | GradNorm: 3.422
#   [Epoch 34 | Batch 550/1568] Loss: 0.5640 | GradNorm: 4.635
#   [Epoch 34 | Batch 600/1568] Loss: 0.5591 | GradNorm: 4.526
#   [Epoch 34 | Batch 650/1568] Loss: 0.8831 | GradNorm: 5.384
#   [Epoch 34 | Batch 700/1568] Loss: 0.5678 | GradNorm: 4.352
#   [Epoch 34 | Batch 750/1568] Loss: 0.6553 | GradNorm: 4.226
#   [Epoch 34 | Batch 800/1568] Loss: 0.8415 | GradNorm: 4.911
#   [Epoch 34 | Batch 850/1568] Loss: 0.5436 | GradNorm: 4.036
#   [Epoch 34 | Batch 900/1568] Loss: 0.7954 | GradNorm: 5.171
#   [Epoch 34 | Batch 950/1568] Loss: 0.6446 | GradNorm: 4.266
#   [Epoch 34 | Batch 1000/1568] Loss: 0.5301 | GradNorm: 3.977
#   [Epoch 34 | Batch 1050/1568] Loss: 0.5713 | GradNorm: 4.065
#   [Epoch 34 | Batch 1100/1568] Loss: 0.6428 | GradNorm: 4.936
#   [Epoch 34 | Batch 1150/1568] Loss: 0.6159 | GradNorm: 4.112
#   [Epoch 34 | Batch 1200/1568] Loss: 0.6809 | GradNorm: 4.638
#   [Epoch 34 | Batch 1250/1568] Loss: 0.4818 | GradNorm: 3.830
#   [Epoch 34 | Batch 1300/1568] Loss: 0.4946 | GradNorm: 3.955
#   [Epoch 34 | Batch 1350/1568] Loss: 0.6727 | GradNorm: 4.511
#   [Epoch 34 | Batch 1400/1568] Loss: 0.7435 | GradNorm: 4.584
#   [Epoch 34 | Batch 1450/1568] Loss: 0.6134 | GradNorm: 4.781
#   [Epoch 34 | Batch 1500/1568] Loss: 0.5713 | GradNorm: 3.961
#   [Epoch 34 | Batch 1550/1568] Loss: 0.6283 | GradNorm: 4.521
#
# Epoch 34/40 | Loss: 0.5854 | Perplexity: 1.8 | LR: 0.000083 | Time: 51.8s  ✓ Best model saved!
#
#   [Epoch 35 | Batch  50/1568] Loss: 0.3778 | GradNorm: 3.654
#   [Epoch 35 | Batch 100/1568] Loss: 0.2875 | GradNorm: 2.716
#   [Epoch 35 | Batch 150/1568] Loss: 0.5715 | GradNorm: 4.293
#   [Epoch 35 | Batch 200/1568] Loss: 0.4464 | GradNorm: 3.853
#   [Epoch 35 | Batch 250/1568] Loss: 0.5683 | GradNorm: 4.745
#   [Epoch 35 | Batch 300/1568] Loss: 0.3365 | GradNorm: 3.319
#   [Epoch 35 | Batch 350/1568] Loss: 0.6907 | GradNorm: 4.546
#   [Epoch 35 | Batch 400/1568] Loss: 0.5577 | GradNorm: 4.602
#   [Epoch 35 | Batch 450/1568] Loss: 0.5560 | GradNorm: 4.222
#   [Epoch 35 | Batch 500/1568] Loss: 0.6180 | GradNorm: 4.421
#   [Epoch 35 | Batch 550/1568] Loss: 0.5318 | GradNorm: 4.302
#   [Epoch 35 | Batch 600/1568] Loss: 0.5916 | GradNorm: 4.435
#   [Epoch 35 | Batch 650/1568] Loss: 0.5576 | GradNorm: 4.376
#   [Epoch 35 | Batch 700/1568] Loss: 0.5923 | GradNorm: 4.270
#   [Epoch 35 | Batch 750/1568] Loss: 0.5744 | GradNorm: 4.287
#   [Epoch 35 | Batch 800/1568] Loss: 0.5008 | GradNorm: 4.012
#   [Epoch 35 | Batch 850/1568] Loss: 0.4327 | GradNorm: 4.082
#   [Epoch 35 | Batch 900/1568] Loss: 0.6251 | GradNorm: 4.316
#   [Epoch 35 | Batch 950/1568] Loss: 0.8378 | GradNorm: 4.728
#   [Epoch 35 | Batch 1000/1568] Loss: 0.8564 | GradNorm: 5.375
#   [Epoch 35 | Batch 1050/1568] Loss: 0.5893 | GradNorm: 4.242
#   [Epoch 35 | Batch 1100/1568] Loss: 0.5882 | GradNorm: 3.905
#   [Epoch 35 | Batch 1150/1568] Loss: 0.4370 | GradNorm: 3.748
#   [Epoch 35 | Batch 1200/1568] Loss: 0.5526 | GradNorm: 4.362
#   [Epoch 35 | Batch 1250/1568] Loss: 0.4336 | GradNorm: 3.451
#   [Epoch 35 | Batch 1300/1568] Loss: 0.5894 | GradNorm: 4.275
#   [Epoch 35 | Batch 1350/1568] Loss: 0.6630 | GradNorm: 4.714
#   [Epoch 35 | Batch 1400/1568] Loss: 0.3762 | GradNorm: 3.478
#   [Epoch 35 | Batch 1450/1568] Loss: 0.6599 | GradNorm: 4.766
#   [Epoch 35 | Batch 1500/1568] Loss: 0.7635 | GradNorm: 5.325
#   [Epoch 35 | Batch 1550/1568] Loss: 0.5326 | GradNorm: 3.997
#
# Epoch 35/40 | Loss: 0.5561 | Perplexity: 1.7 | LR: 0.000064 | Time: 51.6s  ✓ Best model saved!
#
#   [SAMPLE at epoch 35]
#   ear amid self on the noble scene in nature . < end > i have devoted my resolution to you , and i will no cause . < end >
#
#   [Epoch 36 | Batch  50/1568] Loss: 0.4336 | GradNorm: 3.612
#   [Epoch 36 | Batch 100/1568] Loss: 0.5233 | GradNorm: 4.048
#   [Epoch 36 | Batch 150/1568] Loss: 0.4890 | GradNorm: 4.344
#   [Epoch 36 | Batch 200/1568] Loss: 0.4636 | GradNorm: 3.557
#   [Epoch 36 | Batch 250/1568] Loss: 0.5572 | GradNorm: 3.876
#   [Epoch 36 | Batch 300/1568] Loss: 0.7905 | GradNorm: 4.641
#   [Epoch 36 | Batch 350/1568] Loss: 0.3667 | GradNorm: 3.389
#   [Epoch 36 | Batch 400/1568] Loss: 0.5099 | GradNorm: 4.130
#   [Epoch 36 | Batch 450/1568] Loss: 0.2850 | GradNorm: 2.854
#   [Epoch 36 | Batch 500/1568] Loss: 0.6459 | GradNorm: 4.569
#   [Epoch 36 | Batch 550/1568] Loss: 0.6706 | GradNorm: 4.584
#   [Epoch 36 | Batch 600/1568] Loss: 0.4839 | GradNorm: 4.383
#   [Epoch 36 | Batch 650/1568] Loss: 0.6514 | GradNorm: 4.983
#   [Epoch 36 | Batch 700/1568] Loss: 0.4625 | GradNorm: 4.179
#   [Epoch 36 | Batch 750/1568] Loss: 0.8137 | GradNorm: 5.102
#   [Epoch 36 | Batch 800/1568] Loss: 0.5324 | GradNorm: 4.027
#   [Epoch 36 | Batch 850/1568] Loss: 0.6621 | GradNorm: 4.463
#   [Epoch 36 | Batch 900/1568] Loss: 0.3976 | GradNorm: 3.570
#   [Epoch 36 | Batch 950/1568] Loss: 0.3719 | GradNorm: 3.780
#   [Epoch 36 | Batch 1000/1568] Loss: 0.4504 | GradNorm: 3.934
#   [Epoch 36 | Batch 1050/1568] Loss: 0.4576 | GradNorm: 3.903
#   [Epoch 36 | Batch 1100/1568] Loss: 0.4220 | GradNorm: 3.730
#   [Epoch 36 | Batch 1150/1568] Loss: 0.5658 | GradNorm: 4.267
#   [Epoch 36 | Batch 1200/1568] Loss: 0.4905 | GradNorm: 3.850
#   [Epoch 36 | Batch 1250/1568] Loss: 0.5693 | GradNorm: 4.389
#   [Epoch 36 | Batch 1300/1568] Loss: 0.5719 | GradNorm: 4.437
#   [Epoch 36 | Batch 1350/1568] Loss: 0.6931 | GradNorm: 4.762
#   [Epoch 36 | Batch 1400/1568] Loss: 0.6245 | GradNorm: 4.457
#   [Epoch 36 | Batch 1450/1568] Loss: 0.5191 | GradNorm: 3.903
#   [Epoch 36 | Batch 1500/1568] Loss: 0.5929 | GradNorm: 4.356
#   [Epoch 36 | Batch 1550/1568] Loss: 0.5857 | GradNorm: 4.409
#
# Epoch 36/40 | Loss: 0.5328 | Perplexity: 1.7 | LR: 0.000048 | Time: 51.6s  ✓ Best model saved!
#
#   [Epoch 37 | Batch  50/1568] Loss: 0.5676 | GradNorm: 3.968
#   [Epoch 37 | Batch 100/1568] Loss: 0.5894 | GradNorm: 4.475
#   [Epoch 37 | Batch 150/1568] Loss: 0.4444 | GradNorm: 3.798
#   [Epoch 37 | Batch 200/1568] Loss: 0.5926 | GradNorm: 4.314
#   [Epoch 37 | Batch 250/1568] Loss: 0.4598 | GradNorm: 4.375
#   [Epoch 37 | Batch 300/1568] Loss: 0.5705 | GradNorm: 4.480
#   [Epoch 37 | Batch 350/1568] Loss: 0.4331 | GradNorm: 3.503
#   [Epoch 37 | Batch 400/1568] Loss: 0.4162 | GradNorm: 3.755
#   [Epoch 37 | Batch 450/1568] Loss: 0.3274 | GradNorm: 2.951
#   [Epoch 37 | Batch 500/1568] Loss: 0.4167 | GradNorm: 3.443
#   [Epoch 37 | Batch 550/1568] Loss: 0.3890 | GradNorm: 3.478
#   [Epoch 37 | Batch 600/1568] Loss: 0.6342 | GradNorm: 4.530
#   [Epoch 37 | Batch 650/1568] Loss: 0.2811 | GradNorm: 2.726
#   [Epoch 37 | Batch 700/1568] Loss: 0.4766 | GradNorm: 3.855
#   [Epoch 37 | Batch 750/1568] Loss: 0.4366 | GradNorm: 3.882
#   [Epoch 37 | Batch 800/1568] Loss: 0.4833 | GradNorm: 4.176
#   [Epoch 37 | Batch 850/1568] Loss: 0.5091 | GradNorm: 4.389
#   [Epoch 37 | Batch 900/1568] Loss: 0.7093 | GradNorm: 4.468
#   [Epoch 37 | Batch 950/1568] Loss: 0.3156 | GradNorm: 3.437
#   [Epoch 37 | Batch 1000/1568] Loss: 0.2923 | GradNorm: 3.227
#   [Epoch 37 | Batch 1050/1568] Loss: 0.5836 | GradNorm: 4.096
#   [Epoch 37 | Batch 1100/1568] Loss: 0.2683 | GradNorm: 3.159
#   [Epoch 37 | Batch 1150/1568] Loss: 0.4663 | GradNorm: 3.649
#   [Epoch 37 | Batch 1200/1568] Loss: 0.4363 | GradNorm: 3.586
#   [Epoch 37 | Batch 1250/1568] Loss: 0.6657 | GradNorm: 4.673
#   [Epoch 37 | Batch 1300/1568] Loss: 0.4660 | GradNorm: 4.024
#   [Epoch 37 | Batch 1350/1568] Loss: 0.4022 | GradNorm: 3.622
#   [Epoch 37 | Batch 1400/1568] Loss: 0.4655 | GradNorm: 4.149
#   [Epoch 37 | Batch 1450/1568] Loss: 0.5811 | GradNorm: 4.348
#   [Epoch 37 | Batch 1500/1568] Loss: 0.6202 | GradNorm: 4.352
#   [Epoch 37 | Batch 1550/1568] Loss: 0.5350 | GradNorm: 3.985
#
# Epoch 37/40 | Loss: 0.5147 | Perplexity: 1.7 | LR: 0.000034 | Time: 51.7s  ✓ Best model saved!
#
#   [Epoch 38 | Batch  50/1568] Loss: 0.4334 | GradNorm: 3.874
#   [Epoch 38 | Batch 100/1568] Loss: 0.3578 | GradNorm: 3.499
#   [Epoch 38 | Batch 150/1568] Loss: 0.5752 | GradNorm: 4.545
#   [Epoch 38 | Batch 200/1568] Loss: 0.3467 | GradNorm: 3.305
#   [Epoch 38 | Batch 250/1568] Loss: 0.5735 | GradNorm: 4.324
#   [Epoch 38 | Batch 300/1568] Loss: 0.6657 | GradNorm: 4.911
#   [Epoch 38 | Batch 350/1568] Loss: 0.4475 | GradNorm: 3.757
#   [Epoch 38 | Batch 400/1568] Loss: 0.4155 | GradNorm: 3.686
#   [Epoch 38 | Batch 450/1568] Loss: 0.5285 | GradNorm: 4.593
#   [Epoch 38 | Batch 500/1568] Loss: 0.5900 | GradNorm: 4.564
#   [Epoch 38 | Batch 550/1568] Loss: 0.6184 | GradNorm: 4.125
#   [Epoch 38 | Batch 600/1568] Loss: 0.3947 | GradNorm: 3.645
#   [Epoch 38 | Batch 650/1568] Loss: 0.4685 | GradNorm: 4.171
#   [Epoch 38 | Batch 700/1568] Loss: 0.3885 | GradNorm: 3.370
#   [Epoch 38 | Batch 750/1568] Loss: 0.5471 | GradNorm: 4.325
#   [Epoch 38 | Batch 800/1568] Loss: 0.4746 | GradNorm: 4.164
#   [Epoch 38 | Batch 850/1568] Loss: 0.4865 | GradNorm: 4.156
#   [Epoch 38 | Batch 900/1568] Loss: 0.4008 | GradNorm: 3.695
#   [Epoch 38 | Batch 950/1568] Loss: 0.5604 | GradNorm: 4.135
#   [Epoch 38 | Batch 1000/1568] Loss: 0.5098 | GradNorm: 4.080
#   [Epoch 38 | Batch 1050/1568] Loss: 0.3895 | GradNorm: 3.775
#   [Epoch 38 | Batch 1100/1568] Loss: 0.4669 | GradNorm: 4.130
#   [Epoch 38 | Batch 1150/1568] Loss: 0.5047 | GradNorm: 4.212
#   [Epoch 38 | Batch 1200/1568] Loss: 0.4697 | GradNorm: 3.755
#   [Epoch 38 | Batch 1250/1568] Loss: 0.7522 | GradNorm: 5.057
#   [Epoch 38 | Batch 1300/1568] Loss: 0.5675 | GradNorm: 3.860
#   [Epoch 38 | Batch 1350/1568] Loss: 0.3909 | GradNorm: 3.786
#   [Epoch 38 | Batch 1400/1568] Loss: 0.4339 | GradNorm: 3.779
#   [Epoch 38 | Batch 1450/1568] Loss: 0.5405 | GradNorm: 4.313
#   [Epoch 38 | Batch 1500/1568] Loss: 0.8525 | GradNorm: 5.384
#   [Epoch 38 | Batch 1550/1568] Loss: 0.5668 | GradNorm: 4.272
#
# Epoch 38/40 | Loss: 0.4961 | Perplexity: 1.6 | LR: 0.000024 | Time: 51.8s  ✓ Best model saved!
#
#   [Epoch 39 | Batch  50/1568] Loss: 0.4651 | GradNorm: 4.069
#   [Epoch 39 | Batch 100/1568] Loss: 0.3791 | GradNorm: 3.700
#   [Epoch 39 | Batch 150/1568] Loss: 0.3938 | GradNorm: 3.983
#   [Epoch 39 | Batch 200/1568] Loss: 0.4239 | GradNorm: 3.464
#   [Epoch 39 | Batch 250/1568] Loss: 0.6334 | GradNorm: 4.966
#   [Epoch 39 | Batch 300/1568] Loss: 0.3749 | GradNorm: 3.829
#   [Epoch 39 | Batch 350/1568] Loss: 0.3566 | GradNorm: 3.284
#   [Epoch 39 | Batch 400/1568] Loss: 0.4974 | GradNorm: 4.284
#   [Epoch 39 | Batch 450/1568] Loss: 0.4909 | GradNorm: 4.267
#   [Epoch 39 | Batch 500/1568] Loss: 0.5461 | GradNorm: 4.182
#   [Epoch 39 | Batch 550/1568] Loss: 0.3123 | GradNorm: 3.091
#   [Epoch 39 | Batch 600/1568] Loss: 0.3794 | GradNorm: 3.737
#   [Epoch 39 | Batch 650/1568] Loss: 0.4476 | GradNorm: 3.679
#   [Epoch 39 | Batch 700/1568] Loss: 0.4228 | GradNorm: 3.679
#   [Epoch 39 | Batch 750/1568] Loss: 0.3913 | GradNorm: 3.438
#   [Epoch 39 | Batch 800/1568] Loss: 0.5301 | GradNorm: 4.310
#   [Epoch 39 | Batch 850/1568] Loss: 0.5489 | GradNorm: 4.166
#   [Epoch 39 | Batch 900/1568] Loss: 0.5421 | GradNorm: 3.943
#   [Epoch 39 | Batch 950/1568] Loss: 0.4787 | GradNorm: 4.217
#   [Epoch 39 | Batch 1000/1568] Loss: 0.4630 | GradNorm: 3.663
#   [Epoch 39 | Batch 1050/1568] Loss: 0.6175 | GradNorm: 4.395
#   [Epoch 39 | Batch 1100/1568] Loss: 0.5402 | GradNorm: 4.351
#   [Epoch 39 | Batch 1150/1568] Loss: 0.3862 | GradNorm: 3.754
#   [Epoch 39 | Batch 1200/1568] Loss: 0.5126 | GradNorm: 3.960
#   [Epoch 39 | Batch 1250/1568] Loss: 0.3911 | GradNorm: 3.630
#   [Epoch 39 | Batch 1300/1568] Loss: 0.7397 | GradNorm: 4.908
#   [Epoch 39 | Batch 1350/1568] Loss: 0.6769 | GradNorm: 5.149
#   [Epoch 39 | Batch 1400/1568] Loss: 0.3806 | GradNorm: 3.585
#   [Epoch 39 | Batch 1450/1568] Loss: 0.6815 | GradNorm: 4.806
#   [Epoch 39 | Batch 1500/1568] Loss: 0.3900 | GradNorm: 3.803
#   [Epoch 39 | Batch 1550/1568] Loss: 0.5419 | GradNorm: 4.245
#
# Epoch 39/40 | Loss: 0.4879 | Perplexity: 1.6 | LR: 0.000016 | Time: 51.9s  ✓ Best model saved!
#
#   [Epoch 40 | Batch  50/1568] Loss: 0.3733 | GradNorm: 3.443
#   [Epoch 40 | Batch 100/1568] Loss: 0.5919 | GradNorm: 4.296
#   [Epoch 40 | Batch 150/1568] Loss: 0.5589 | GradNorm: 4.518
#   [Epoch 40 | Batch 200/1568] Loss: 0.4000 | GradNorm: 4.034
#   [Epoch 40 | Batch 250/1568] Loss: 0.3282 | GradNorm: 3.569
#   [Epoch 40 | Batch 300/1568] Loss: 0.5049 | GradNorm: 4.048
#   [Epoch 40 | Batch 350/1568] Loss: 0.4201 | GradNorm: 3.827
#   [Epoch 40 | Batch 400/1568] Loss: 0.7141 | GradNorm: 4.850
#   [Epoch 40 | Batch 450/1568] Loss: 0.2283 | GradNorm: 2.641
#   [Epoch 40 | Batch 500/1568] Loss: 0.6735 | GradNorm: 5.167
#   [Epoch 40 | Batch 550/1568] Loss: 0.4950 | GradNorm: 4.005
#   [Epoch 40 | Batch 600/1568] Loss: 0.7009 | GradNorm: 4.540
#   [Epoch 40 | Batch 650/1568] Loss: 0.7159 | GradNorm: 4.708
#   [Epoch 40 | Batch 700/1568] Loss: 0.6155 | GradNorm: 4.568
#   [Epoch 40 | Batch 750/1568] Loss: 0.6780 | GradNorm: 4.710
#   [Epoch 40 | Batch 800/1568] Loss: 0.4977 | GradNorm: 3.726
#   [Epoch 40 | Batch 850/1568] Loss: 0.4392 | GradNorm: 3.764
#   [Epoch 40 | Batch 900/1568] Loss: 0.5694 | GradNorm: 4.492
#   [Epoch 40 | Batch 950/1568] Loss: 0.4069 | GradNorm: 3.653
#   [Epoch 40 | Batch 1000/1568] Loss: 0.4696 | GradNorm: 3.987
#   [Epoch 40 | Batch 1050/1568] Loss: 0.4771 | GradNorm: 3.739
#   [Epoch 40 | Batch 1100/1568] Loss: 0.6105 | GradNorm: 4.655
#   [Epoch 40 | Batch 1150/1568] Loss: 0.6396 | GradNorm: 4.795
#   [Epoch 40 | Batch 1200/1568] Loss: 0.5739 | GradNorm: 4.380
#   [Epoch 40 | Batch 1250/1568] Loss: 0.5800 | GradNorm: 4.159
#   [Epoch 40 | Batch 1300/1568] Loss: 0.4024 | GradNorm: 3.864
#   [Epoch 40 | Batch 1350/1568] Loss: 0.6577 | GradNorm: 4.551
#   [Epoch 40 | Batch 1400/1568] Loss: 0.3448 | GradNorm: 3.443
#   [Epoch 40 | Batch 1450/1568] Loss: 0.3024 | GradNorm: 3.415
#   [Epoch 40 | Batch 1500/1568] Loss: 0.4528 | GradNorm: 4.354
#   [Epoch 40 | Batch 1550/1568] Loss: 0.3821 | GradNorm: 3.742
#
# Epoch 40/40 | Loss: 0.4792 | Perplexity: 1.6 | LR: 0.000012 | Time: 51.7s  ✓ Best model saved!
#
#   [SAMPLE at epoch 40]
#   me on what i had created . < end > but she was innocent , that which can relate happy and so many men are now chained a secret to
#
# =======================================================
#   Training finished! Best loss: 0.4792
# =======================================================

# %% [markdown]
# **9. Text Generation**

# %%
seed_texts = [
    "the creature stood before me",
    "darkness surrounded the lonely",
    "my heart was filled with",
    "she looked at him with",
    "the storm began to"
]

print("=" * 50)
print("  GENERATED TEXT SAMPLES")
print("=" * 50)

for i, seed in enumerate(seed_texts):
    result = generate_text_gpu(model, seed, next_words=15, temperature=0.8, greedy=True)
    seed_word_count = len(re.findall(r"\w+|[^\w\s]", seed.lower(), re.UNICODE))
    generated = " ".join(result.split()[seed_word_count:])
    generated = generated.replace("< end >", "").replace("<end>", "").strip()
    print(f"Sentence {i+1}: {seed} {generated}")
# Out:
# ==================================================
#   GENERATED TEXT SAMPLES
# ==================================================
# Sentence 1: the creature stood before me .  i was unable to discover what his sufferings were towards me
# Sentence 2: darkness surrounded the lonely , and the old man beheld no other prospect .  he pointed
# Sentence 3: my heart was filled with pleasure to the horror of his employment .  “ i am happy
# Sentence 4: she looked at him with a language of her lover by the aid of an old man , who was
# Sentence 5: the storm began to be perceived with the approach of a kind and danced amidst the clouds . <

# %% [markdown]
# **10. RNN vs LSTM**

# %%
import matplotlib.pyplot as plt

rnn_loss = [
    6.2714, 5.7492, 5.5522, 5.4364, 5.3532,
    5.3125, 5.2690, 5.2461, 5.2398, 5.2112,
    5.2090, 5.1932, 5.1792, 5.1689, 5.1667,
    5.1588, 5.1636, 5.1492, 5.1470, 5.1330,
    5.1427, 5.1432, 5.1386, 5.1766, 4.9870,
    4.9376, 4.9031, 4.8778, 4.8552, 4.8576
]

lstm_loss = loss_history

epochs_rnn  = list(range(1, len(rnn_loss) + 1))
epochs_lstm = list(range(1, len(lstm_loss) + 1))

plt.figure(figsize=(10, 5))
plt.plot(epochs_rnn,  rnn_loss,  label="RNN",  color="steelblue",  linewidth=2, marker="o", markersize=3)
plt.plot(epochs_lstm, lstm_loss, label="LSTM", color="darkorange", linewidth=2, marker="o", markersize=3)

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("RNN vs LSTM — Training Loss Comparison")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig("rnn_vs_lstm.png", dpi=150)
plt.show()

print(f"RNN  — Best Loss: {min(rnn_loss):.4f}")
print(f"LSTM — Best Loss: {min(lstm_loss):.4f}")
# Out:
# RNN  — Best Loss: 4.8552
# LSTM — Best Loss: 0.4792
